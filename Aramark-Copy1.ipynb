# %%
import pandas as pd
import numpy as np

# %%
attend = pd.read_csv('../data/DIM_ATTENDANCE.csv')
disct = pd.read_csv('../data/DIM_DISCOUNT.csv')
tender = pd.read_csv('../data/DIM_TENDER_MEDIA.csv')

# %%
menu = pd.read_csv('../data/DIM_MENU_ITEM.csv')

# %%
attend.head(3)
# Out:
#     EventID Location  SiteID  POS_SystemID businessDate  TotalAttendance  \
# 0  14895690    Site2       6            93    3/30/2017                0
# 1  14981354    Site2       6            93     4/7/2017            41586
# 2  14995359    Site2       6            93     4/8/2017            33731
#
#    ConcessionAttendance  SuiteAttendance  TotalNumSuites  SuitesInUse  \
# 0                     0                0               0            0
# 1                 36872             1091              70           66
# 2                 29966              876              70           49
#
#    ClubAttendance  MerchandiseAttendance
# 0               0                      0
# 1            2468                  41586
# 2            1833                  33731

# %%
disct.head(3)
# Out:
#    discountID  organizationID  locationID  SiteID  POS_SystemID  \
# 0     6268161           10001        2021       6            93
# 1     6268163           10001        2021       6            93
# 2     6268165           10001        2021       6            93
#
#    discountMasterID  discountReportID              name        nameMaster  \
# 0           6268160           6268160   AAA DINING CARD   AAA DINING CARD
# 1           6268162           6268162  AMEX DINING CARD  AMEX DINING CARD
# 2           6268164           6268164        CHILD ITEM        CHILD ITEM
#
#    categoryGroupID1   ...     reportFlag  align  masterAlias  xbrCategory  \
# 0               NaN   ...              1      0            0          NaN
# 1               NaN   ...              1      0            0          NaN
# 2               NaN   ...              1      0            0          NaN
#
#    customerInfoType  lastUsedDatetime  extRef1Master  extRef2  extRef2Master  \
# 0               NaN               NaN            NaN      NaN            NaN
# 1               NaN               NaN            NaN      NaN            NaN
# 2               NaN               NaN            NaN      NaN            NaN
#
#    extRef1
# 0      NaN
# 1      NaN
# 2      NaN
#
# [3 rows x 27 columns]

# %%
menu.tail(10)
# Out:
#        menuItemID  organizationID  locationID  SiteID  POS_SystemID  \
# 12053     7838500           10001        3000       6            93
# 12054     7838501           10001        3000       6            93
# 12055     7838550           10001        3000       6            93
# 12056     7838551           10001        3000       6            93
# 12057     7838552           10001        3000       6            93
# 12058     7838601           10001        3000       6            93
# 12059     7838651           10001        3000       6            93
# 12060     7838653           10001        3000       6            93
# 12061     7838654           10001        3000       6            93
# 12062     7864900           10001        3000       6            93
#
#        menuItemMasterID  menuItemReportID   menuItemName1  majorGroupID  \
# 12053           6288346           6288346   1/2 DOM DRAFT       6281768
# 12054           6288348           6288348  1/2 PREM DRAFT       6281768
# 12055           6288166           6288166     1/2 DOM CAN       6281768
# 12056           6290030           6290030    1/2 PREM CAN       6281768
# 12057           6294138           6294138       1/2 WATER       6281758
# 12058           7838600           7838600   1/2 TOP SHELF       6281766
# 12059           7838650           7838650        1/2 WELL       6281766
# 12060           7838652           7838652      1/2 DOUBLE       6281766
# 12061           6292212           6292212        1/2 WINE       6281767
# 12062           6300580           6300580    BEEF LO MEIN       6281773
#
#        majorGroupMasterID          ...           masterAlias  align  \
# 12053             6268342          ...                     0      0
# 12054             6268342          ...                     0      0
# 12055             6268342          ...                     0      0
# 12056             6268342          ...                     0      0
# 12057             6268334          ...                     0      0
# 12058             6268338          ...                     0      0
# 12059             6268338          ...                     0      0
# 12060             6268338          ...                     0      0
# 12061             6268340          ...                     0      0
# 12062             6273090          ...                     0      0
#
#        xbrCategory  customerInfoType  myInvUpdateFlag  lastUpdateDatetime  \
# 12053          NaN               NaN                1     8/28/2017 17:02
# 12054          NaN               NaN                1     8/28/2017 17:02
# 12055          NaN               NaN                1     8/28/2017 17:10
# 12056          NaN               NaN                1     8/28/2017 17:10
# 12057          NaN               NaN                1     8/28/2017 17:00
# 12058          NaN               NaN                1     8/28/2017 17:00
# 12059          NaN               NaN                1     8/28/2017 17:00
# 12060          NaN               NaN                1     8/28/2017 17:02
# 12061          NaN               NaN                1     8/28/2017 17:02
# 12062          NaN               NaN                1     9/25/2017 13:58
#
#        lastUsedDatetime  doNotReport  familyGroupNameMaster  \
# 12053               NaN          NaN         DOM DRAFT BEER
# 12054               NaN          NaN         DOM DRAFT BEER
# 12055               NaN          NaN           DOM CAN BEER
# 12056               NaN          NaN           DOM CAN BEER
# 12057               NaN          NaN           NA BTL WATER
# 12058               NaN          NaN                  VODKA
# 12059               NaN          NaN                  VODKA
# 12060               NaN          NaN                  VODKA
# 12061               NaN          NaN             GLS MERLOT
# 12062               NaN          NaN              APPETIZER
#
#        majorGroupNameMaster
# 12053                  BEER
# 12054                  BEER
# 12055                  BEER
# 12056                  BEER
# 12057           NA BEVERAGE
# 12058               LIQUOR
# 12059               LIQUOR
# 12060               LIQUOR
# 12061                 WINE
# 12062          PREMIUM FOOD
#
# [10 rows x 37 columns]

# %%
menu.rename(columns={'menuItemID': 'recordID'}, inplace=True)
menu.head()
# Out:
#    recordID  organizationID  locationID  SiteID  POS_SystemID  \
# 0   8122034             200           1      15            16
# 1   7841299             200           1      15            16
# 2   7726145             200           1      15            16
# 3   7403682             200           1      15            16
# 4   5351336             200           1      15            16
#
#    menuItemMasterID  menuItemReportID     menuItemName1  majorGroupID  \
# 0           8122033           8122033  Gluten Free Juic        811998
# 1           7841298           7841298     Buff Chix Stk        811996
# 2           7726144           7726144       Whole Fruit        811996
# 3           7403681           7403681       Coffee Cake        811996
# 4           5351335           5351335     Dog 90Min IPA        812002
#
#    majorGroupMasterID          ...           masterAlias  align  xbrCategory  \
# 0              811998          ...                     0      0          NaN
# 1              811996          ...                     0      0          NaN
# 2              811996          ...                     0      0          NaN
# 3              811996          ...                     0      0          NaN
# 4              812002          ...                     0      0          NaN
#
#    customerInfoType  myInvUpdateFlag  lastUpdateDatetime  lastUsedDatetime  \
# 0               NaN    1/1/1900 0:00    11/13/2015 10:30               NaN
# 1               NaN    1/1/1900 0:00     9/27/2012 18:10               NaN
# 2               NaN    1/1/1900 0:00     3/19/2015 14:21               NaN
# 3               NaN    1/1/1900 0:00      7/29/2015 9:46               NaN
# 4               NaN    1/1/1900 0:00     8/25/2011 10:49               NaN
#
#    doNotReport  familyGroupNameMaster  majorGroupNameMaster
# 0          NaN                    NaN                   NaN
# 1          NaN                    NaN                   NaN
# 2          NaN                    NaN                   NaN
# 3          NaN                    NaN                   NaN
# 4          NaN                    NaN                   NaN
#
# [5 rows x 37 columns]

# %%
tender.head(3)
# Out:
#    tenderMediaID  organizationID  locationID  SiteID  POS_SystemID  \
# 0        6272607           10001        2021       6            93
# 1        6272609           10001        2021       6            93
# 2        6272611           10001        2021       6            93
#
#    tenderMediaMasterID  tenderMediaReportID        name  type  subType  \
# 0              6272606              6272606        VISA     1        4
# 1              6272608              6272608  MASTERCARD     1        4
# 2              6272610              6272610    DISCOVER     1        4
#
#    tenderMediaPOSRef  hideAcctNum  customerInfoType  chargeTipID  reportFlag
# 0                200            1               NaN    6268022.0           1
# 1                201            1               NaN    6268022.0           1
# 2                202            1               NaN    6268022.0           1

# %% [markdown]
# ## FACT SITES

# %% [markdown]
# ### Chunk up the data and read it in 100,000 records at a time.

# %%
fact = pd.read_csv('../data/FACT_Sites_2017.csv', parse_dates=True,
                   na_values='NULL', chunksize=100000, iterator=True,
                       
                      usecols=['guestCheckLineItemID', 'Site', 'revenueCenterID',
                               'Location', 'orderTypeID', 'fixedPeriod',
                               'guestCheckID', 'posTransRef', 'serviceRoundNum',
                               'lineNum', 'seatNum', 'detailType', 'detailDesc',
                               'recordID', 'posRef', 'priceLevel', 'uwsID',
                               'workstation', 'checkEmployeeID', 
                               'managerEmployeeID', 'voidFlag', 'reasonCode',
                               'lineCount', 'lineTotal', 'lineTotal2',
                               'reportLineCount', 'reportLineTotal'])

# %%
#df = pd.concat(fact, ignore_index=True)
df = fact.get_chunk()
df.head()
# Out:
#    guestCheckLineItemID   Site  revenueCenterID          Location  \
# 0             132451542  Site1           811898  C04 LIBERTY GRLL
# 1             132605169  Site1           811898  C04 LIBERTY GRLL
# 2             132737533  Site1           811898  C04 LIBERTY GRLL
# 3             131944665  Site1           811869   123 PHILLY FAVS
# 4             132276245  Site1           811867    120 PENN PIZZA
#
#    orderTypeID  fixedPeriod  guestCheckID  posTransRef  serviceRoundNum  \
# 0       146867           57      22840740         7859                1
# 1       146867           59      22850584         7124                1
# 2       146867           60      22859884         7124                1
# 3       146867           48      22805115          169                1
# 4       146867           54      22828624         3194                1
#
#    lineNum       ...         workstation  checkEmployeeID managerEmployeeID  \
# 0       21       ...               304_2           841293               NaN
# 1       21       ...               304_2           841293               NaN
# 2       21       ...               304_2           841293               NaN
# 3       21       ...               123_4           815460               NaN
# 4       21       ...               120_2           836854               NaN
#
#    voidFlag  reasonCode  lineCount  lineTotal lineTotal2  reportLineCount  \
# 0         0           0          1       10.0        0.0                0
# 1         0           0          1       11.0        0.0                0
# 2         0           0          1       11.0        0.0                0
# 3         0           0          1        6.0        0.0                0
# 4         0           0          1       11.0        0.0                0
#
#    reportLineTotal
# 0             10.0
# 1             11.0
# 2             11.0
# 3              6.0
# 4             11.0
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Managers associated with transactions.

# %%
df[df.managerEmployeeID.notnull()].groupby('managerEmployeeID').size().sort_values(ascending=False).head()
# Out:
# managerEmployeeID
# 940503.0      189
# 18582428.0    185
# 18582427.0    121
# 8523064.0      99
# 8189191.0      91
# dtype: int64

# %%
df.Location.value_counts().head()
# Out:
# 129 LIBERTY GRLL    3948
# 102 CHCKIE PETES    3368
# 121 LIBERTY GRLL    2573
# 138 LIBERTY GRLL    2565
# 119 CHCKIE PETES    2458
# Name: Location, dtype: int64

# %% [markdown]
# ### We have a vendor called 'NOT IN USE'.

# %%
df[df.Location == 'NOT IN USE'].head()
# Out:
#       guestCheckLineItemID   Site  revenueCenterID    Location  orderTypeID  \
# 1214             119067123  Site1         18422354  NOT IN USE       146867
# 1533             119065989  Site1         18422354  NOT IN USE       146867
# 1639             119065703  Site1         18422354  NOT IN USE       146867
# 2777             119066559  Site1         18422354  NOT IN USE       146867
# 2893             119065515  Site1         18422354  NOT IN USE       146867
#
#       fixedPeriod  guestCheckID  posTransRef  serviceRoundNum  lineNum  \
# 1214           83      21897076         7859                1       21
# 1533           78      21856981         3405                1       22
# 1639           76      21851183         3604                1       21
# 2777           81      21865296         1250                1       23
# 2893           75      21846868         3339                1       22
#
#            ...         workstation  checkEmployeeID managerEmployeeID  \
# 1214       ...               428_1         20758802               NaN
# 1533       ...               428_1         20758802               NaN
# 1639       ...               428_1         20758802               NaN
# 2777       ...               428_1         20758802               NaN
# 2893       ...               428_1         20758802               NaN
#
#       voidFlag  reasonCode  lineCount  lineTotal lineTotal2  reportLineCount  \
# 1214         0           0          1       10.0        0.0                0
# 1533         0           0          1        9.0        0.0                0
# 1639         0           0          1        9.0        0.0                0
# 2777         0           0          1        8.0        0.0                0
# 2893         0           0          1       10.0        0.0                0
#
#       reportLineTotal
# 1214             10.0
# 1533              9.0
# 1639              9.0
# 2777              8.0
# 2893             10.0
#
# [5 rows x 27 columns]

# %% [markdown]
# ### We have Locations that are 1:1 associated with revenueCenterID and multiple workstations per Location.

# %%
df.groupby(['Location', 'revenueCenterID','uwsID']).size()
# Out:
# Location          revenueCenterID  uwsID
# 101 PENN PIZZA    811852           812067      259
#                                    812069      519
#                                    812070      277
#                                    812071      440
#                                    812072      229
#                                    812075      238
# 102 AB PORT       18422348         18422359    119
# 102 CHCKIE PETES  811853           812076      642
#                                    812077      534
#                                    812078      508
#                                    812081      727
#                                    812082      401
#                                    812083      556
# 103 Miller Port   18422350         812234      110
# 104 PHILLY FAVS   811854           812084      178
#                                    812087      331
#                                    812088      427
#                                    812089      383
#                                    812090      275
# 106 PENN PIZZA    811855           812093      120
#                                    812094      367
#                                    812095      451
#                                    812096      212
# 108 PHILLY FAVS   18878470         18878952    339
#                                    18878953      4
#                                    18878954    354
#                                    18878955    315
#                                    18878956    110
#                                    18878957    160
# 109 MARKET ST DE  811857           812101      173
#                                               ...
# CPBE1 BEER GRDN   18878861         18878744    243
#                                    18878854    246
# CPBW1 BEER GRDN   18878862         812063      229
#                                    18878867    202
# CW1 WEST  MARKET  811924           816569      264
#                                    18878875    266
#                                    18878876    186
#                                    18878879    107
#                                    18878880    314
#                                    18878881     14
#                                    18878882    309
# CW2 CHEESESTEAK   811927           18878851    367
# CW5 CHEESESTEAK   811919           147073        7
# CW6 NACHO         811925           18878801     97
# DO NOT USE        881214           147073        2
#                                    18878801     10
# NOT IN USE        811874           812557       18
#                   18422354         18878979    124
# P011 TD CLUB      18422301         18422368    385
#                                    18422369    447
#                                    18422370    205
#                                    18422371     50
# P03 MILLER TENT   20489152         812236      219
#                                    812237       32
#                                    812240       17
#                                    812241        8
#                                    812242        3
#                                    812243      196
# PC PRESIDENTS BR  811914           812064      199
# SP09 SUITES PORT  811917           18878866     98
# Length: 391, dtype: int64

# %% [markdown]
# ### Makes a function that groups menuItemName1 by the guestCheckID. Now we have all receipt items provided a chunk from the csv file.

# %%
def generateMarket(dfIter):
    masterMenuList = list()
    for chunk in dfIter:
        m_faqs = menu.merge(chunk)
        basketList = m_faqs.groupby('guestCheckID')['menuItemName1'].apply(list)
        for basket in basketList:
            masterMenuList.append(basket)
    return masterMenuList

# %%
allBaskets = generateMarket(fact)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2821: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %%
allBaskets
# Out:
# [['Chocolate Milk'],
#  ['Souvenir Soda', 'Snapple Tea'],
#  ['Bass Fresh Fries'],
#  ['20oz Water'],
#  ['20oz G2 LemonLim'],
#  ['20oz Water'],
#  ['Liq Tier 2 '],
#  ['CP 3.25oz Cup'],
#  ['Snapple Apple'],
#  ['Liq Tier 2 '],
#  ['Liq Tier 2 '],
#  ['Liq Tier 2 '],
#  ['Roll Cheesesteak'],
#  ['Cup Smoothie'],
#  ['Pretzel Braided'],
#  ['Pretzel Braided'],
#  ['Liq Tier 2 '],
#  ['Pretzel Braided'],
#  ['Pretzel Braided'],
#  ['Bacon Mac Burger'],
#  ['Bass Fresh Fries'],
#  ['Liq Tier 2 '],
#  ['Small Soda', 'Wine Spark White', 'Liq Tier 2 ', 'Wht Zin Split'],
#  ['Liq Tier 2 ', 'Cup Smoothie'],
#  ['Small Soda', 'Wine Spark Red'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['Small Soda'],
#  ['Liq Tier 2 '],
#  ['2lb Tender Fd Tr'],
#  ['20oz Water'],
#  ['Chard Split'],
#  ['Small Soda', 'Small Soda', 'Hot Dog Eagles'],
#  ['20oz Water', 'Cup Frozen Drink', 'Liq Tier 2 '],
#  ['Wine 187 Cab', 'Wine Spark Red', 'Domestic Draft', 'Chard Split'],
#  ['Personal Pizza'],
#  ['Domestic Draft'],
#  ['Pretzel Braided'],
#  ['Snapple Apple'],
#  ['Snapple Tea'],
#  ['20oz Water'],
#  ['Small Soda', '20oz Water'],
#  ['20oz G2 LemonLim'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['Small Soda', 'Loop Pretzel'],
#  ['16oz Heineken'],
#  ['20oz Water'],
#  ['CP Fry Cup'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['Snapple Tea'],
#  ['Goose Island', 'Bass Chz Burger'],
#  ['CP Fry Cup'],
#  ['20oz Water'],
#  ['CP Tender Tray'],
#  ['16oz Coors Light', 'Hot Dog Eagles'],
#  ['Liq Tier 2 '],
#  ['Hot Dog Eagles'],
#  ['Miller Lt Can'],
#  ['Roll Cheesesteak'],
#  ['20oz Water', 'Hot Dog Eagles', 'CP Fry Cup'],
#  ['20oz Water'],
#  ['Snapple Tea'],
#  ['Loop Pretzel'],
#  ['Coke Bottle'],
#  ['16oz IPA Goose', '16oz IPA Goose'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['Souvenir Draft'],
#  ['2lb Tender Fd Tr', '20oz Water', 'Roll Cheesesteak'],
#  ['16oz Raz Rita', '20oz Water'],
#  ['Roll Cheesesteak'],
#  ['16oz Shandy', '20oz Water', 'Loop Pretzel'],
#  ['Wine 187 Cab'],
#  ['20oz Water'],
#  ['Bass Chz Burger', '20oz Water'],
#  ['Domestic Draft', 'Roll Cheesesteak', 'CP Fry Cup'],
#  ['CP Buff Tenders', 'CP Tender Tray', 'CP Fry Cup'],
#  ['20oz Water'],
#  ['20oz Water', 'Pretzel Braided'],
#  ['20oz Water'],
#  ['Bass Chz Burger', '20oz Water'],
#  ['Small Soda', 'Tony Luke Roll'],
#  ['20oz Water'],
#  ['20oz Water', 'CP Fry Cup'],
#  ['20oz Water', 'CP Tender Tray'],
#  ['20oz Water'],
#  ['Bass Fresh Fries', '20oz Water'],
#  ['16oz IPA Goose'],
#  ['20oz Water'],
#  ['Hot Dog Eagles'],
#  ['Souvenir Draft'],
#  ['Pretzel Braided'],
#  ['2lb Tender Fd Tr'],
#  ['Frozen Marg'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['Snapple Half'],
#  ['20oz Water'],
#  ['Small Soda',
#   '20oz Water',
#   'Hot Dog Eagles',
#   'Roll Cheesesteak',
#   'CP Fry Cup'],
#  ['16oz Shock Top'],
#  ['20oz Water'],
#  ['Personal Pizza'],
#  ['Tony Luke Roll'],
#  ['16oz Redds', '16oz Shandy'],
#  ['Miller Lt Can'],
#  ['Domestic Draft'],
#  ['CP Fry Cup'],
#  ['Chard Split'],
#  ['Souvenir Soda'],
#  ['Loop Pretzel'],
#  ['20oz Water'],
#  ['Coke Bottle'],
#  ['Hot Dog Eagles'],
#  ['Picnic Burger', 'Souvenir Soda'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['Liq Tier 2 ', 'Liq Tier 3 '],
#  ['CP Buff Tenders',
#   '20oz Water',
#   '20oz Water',
#   'CP Tender Tray',
#   'CP Fry Cup'],
#  ['Pretzel Braided'],
#  ['Picnic Burger'],
#  ['20oz Water', 'CP Fry Cup'],
#  ['Premium Draft'],
#  ['Bud Light Can'],
#  ['20oz Water', 'Hot Dog Eagles'],
#  ['20oz Water'],
#  ['Hot Dog Eagles'],
#  ['Domestic Draft'],
#  ['20oz Water'],
#  ['Snapple Apple'],
#  ['CP Fry Cup'],
#  ['Hot Dog Eagles'],
#  ['Hot Dog Eagles'],
#  ['CP Small Fry'],
#  ['20oz Water'],
#  ['CP Tender Tray'],
#  ['20oz Water', 'Roll Cheesesteak'],
#  ['CP Fry Cup'],
#  ['20oz Water', '20oz Water'],
#  ['Small Soda', '20oz Water', 'CP Tender Tray', 'CP Fry Cup'],
#  ['CP Buff Tenders',
#   '20oz Water',
#   '20oz Water',
#   'Roll Cheesesteak',
#   'Roll Cheesesteak',
#   'Diet Coke Btl'],
#  ['Snapple Tea'],
#  ['Souvenir Soda'],
#  ['Sausage Italian', 'Diet Coke Btl'],
#  ['French Fries'],
#  ['Liq Tier 2 '],
#  ['20oz Water'],
#  ['Diet Coke Btl'],
#  ['Souvenir Soda'],
#  ['20oz Water', 'CP Tender Tray'],
#  ['Goose Island', 'Goose Island', 'Goose Island', '20oz Water', '20oz Water'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['20oz Gatorade Fr'],
#  ['20oz Water', 'CP Tender Tray'],
#  ['Souvenir Soda'],
#  ['Loop Pretzel', 'Loop Pretzel'],
#  ['CP Fry Cup'],
#  ['Mich Ultra Btl'],
#  ['16oz IPA Goose'],
#  ['1L Water'],
#  ['Snapple Tea'],
#  ['Snap Diet Peach'],
#  ['Souvenir Soda'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['Souvenir Soda'],
#  ['Snapple Tea'],
#  ['Bass Fresh Fries'],
#  ['20oz Water'],
#  ['CP Small Fry'],
#  ['Hot Dog Eagles'],
#  ['Roll Cheesesteak'],
#  ['20oz Water'],
#  ['Souvenir Soda', 'CP Fry Cup'],
#  ['Liq Tier 2 ', 'Liq Tier 2 '],
#  ['Small Soda', 'CP Buff Tenders'],
#  ['Roll Cheesesteak'],
#  ['Souvenir Soda'],
#  ['Pretzel Braided'],
#  ['Roll Cheesesteak'],
#  ['14.9 oz Stella', 'Personal Pizza'],
#  ['16oz Blue Moon'],
#  ['20oz Water'],
#  ['Small Soda'],
#  ['Small Soda'],
#  ['20oz Water'],
#  ['Domestic Draft', 'Domestic Draft', 'CP Fry Cup'],
#  ['CP Tender Tray', 'CP Fry Cup'],
#  ['Chard Split'],
#  ['Small Soda'],
#  ['CP Small Fry'],
#  ['20oz Water'],
#  ['Snap Diet Peach'],
#  ['Souvenir Soda'],
#  ['20oz Water'],
#  ['Hot Dog Eagles'],
#  ['Premium Draft', '20oz Water', 'CP Fry Cup'],
#  ['CP Tender Tray'],
#  ['20oz Water', 'Coke Bottle', 'CP Fry Cup'],
#  ['16oz MangoRita'],
#  ['16oz Shock Top', '20oz Water'],
#  ['Personal Pizza', '20oz Water', 'Coke Bottle'],
#  ['Souvenir Soda', 'Souvenir Soda'],
#  ['Loop Pretzel', 'Loop Pretzel'],
#  ['Hot Dog Eagles'],
#  ['20oz Water'],
#  ['CP Small Fry', 'Pretzel Braided'],
#  ['20oz Water'],
#  ['CP Small Fry'],
#  ['Small Soda'],
#  ['Loop Pretzel'],
#  ['2lb Tender Fd Tr', 'Coke Bottle'],
#  ['20oz Water'],
#  ['Souvenir Soda', 'CP Fry Cup'],
#  ['Popcorn Box'],
#  ['Souvenir Soda'],
#  ['20oz Water', 'Liq Tier 2 '],
#  ['Small Soda', 'Small Soda', 'CP Tender Tray', 'CP Fry Cup'],
#  ['CP Tender Tray', 'CP Fry Cup'],
#  ['Angus Burger', 'Angus Burger'],
#  ['Bass Chz Burger', 'Coke Bottle'],
#  ['Loop Pretzel'],
#  ['1L Water'],
#  ['Liq Tier 2 '],
#  ['Small Soda'],
#  ['CP Buff Tenders',
#   'CP Buff Tenders',
#   '20oz Water',
#   '20oz Water',
#   'CP Fry Cup',
#   'CP Fry Cup'],
#  ['Roll Cheesesteak', 'CP Fry Cup'],
#  ['CP Fry Cup'],
#  ['20oz Water'],
#  ['CP Fry Cup'],
#  ['CP Tender Tray'],
#  ['Souvenir Soda'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['Snap Diet Peach'],
#  ['Premium Draft', 'Premium Draft'],
#  ['CP Fry Cup'],
#  ['Tortilla Chp'],
#  ['20oz Water'],
#  ['Personal Pizza'],
#  ['Souvenir Soda', 'CP Tender Tray'],
#  ['Small Soda', 'Small Soda', 'CP Fry Cup', 'CP Fry Cup'],
#  ['CP Fry Cup'],
#  ['Souvenir Soda', '20oz Water'],
#  ['20oz Water'],
#  ['Domestic Draft'],
#  ['20oz Water'],
#  ['Small Soda'],
#  ['CP Fry Cup'],
#  ['CP Fry Cup'],
#  ['20oz Water'],
#  ['20oz Water', '20oz Water'],
#  ['Hot Dog Eagles'],
#  ['2lb Tender Fd Tr'],
#  ['Diet Coke Btl'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['Roll Cheesesteak', 'CP Fry Cup'],
#  ['Small Soda'],
#  ['Souvenir Soda'],
#  ['Souvenir Soda'],
#  ['20oz Water'],
#  ['Souvenir Soda'],
#  ['20oz Water'],
#  ['14.9 oz Stella'],
#  ['Souvenir Soda'],
#  ['20oz Water'],
#  ['Bud Light Can', 'Bud Can'],
#  ['CP Tender Tray'],
#  ['20oz Water'],
#  ['Souvenir Soda', '20oz Water', 'Popcorn Box'],
#  ['Souvenir Soda', 'Pretzel Braided'],
#  ['20oz Water'],
#  ['16oz Straw Rita'],
#  ['Sausage Italian'],
#  ['Small Soda', 'Personal Pizza'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['Bottomless Pop'],
#  ['20oz Water'],
#  ['1L Water', '20oz Water'],
#  ['CP Fry Cup'],
#  ['Snapple Tea'],
#  ['Souvenir Soda'],
#  ['Diet Coke Btl'],
#  ['CP Fry Cup'],
#  ['IC Sundae ', 'IC Sundae ', '20oz Water', '20oz Water'],
#  ['CP Tender Tray'],
#  ['Angus Burger'],
#  ['Souvenir Soda', 'Souvenir Soda'],
#  ['Margherita Pizza', 'Shrimp Tempura R', 'French Fries'],
#  ['Pretzel Braided'],
#  ['16oz Shock Top', '16oz Shock Top'],
#  ['Loop Pretzel'],
#  ['Chicken Caesar', '20oz Water'],
#  ['Liq Tier 2 '],
#  ['French Fries'],
#  ['Small Soda', 'Bud Can'],
#  ['Angus Burger', 'French Fries'],
#  ['2lb Tender Fd Tr', '20oz Water'],
#  ['Margherita Pizza', 'Coke Bottle'],
#  ['Souvenir Soda', 'Souvenir Soda'],
#  ['CP Tender Tray', 'CP Tender Tray', 'CP Fry Cup'],
#  ['Pretzel Braided'],
#  ['Liq Tier 2 '],
#  ['16oz Sierra Nev'],
#  ['CP Tender Tray'],
#  ['Bud Can', 'CP Tender Tray', 'CP Fry Cup'],
#  ['Souvenir Soda', '20oz Water'],
#  ['Souvenir Soda'],
#  ['Hot Dog Eagles'],
#  ['20oz Water'],
#  ['Domestic Draft'],
#  ['Hot Dog Eagles'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['Personal Pizza'],
#  ['20oz Water', '20oz Water'],
#  ['1L Water'],
#  ['Plain Philly Fry'],
#  ['French Fries'],
#  ['Margherita Pizza'],
#  ['Diet Coke Btl'],
#  ['1L Water'],
#  ['Domestic Beer'],
#  ['20oz Water'],
#  ['Bass Fresh Fries'],
#  ['20oz Water'],
#  ['16oz Crispen'],
#  ['CP Tender Tray'],
#  ['Small Soda', 'Hot Dog Eagles', 'Hot Dog Eagles'],
#  ['20oz Water', '20oz Water', 'Roll Cheesesteak'],
#  ['Snapple Tea'],
#  ['Small Soda'],
#  ['16oz Shandy', '16oz Shandy'],
#  ['Diet Coke Btl'],
#  ['20oz Water'],
#  ['Snapple Tea'],
#  ['Roll Cheesesteak'],
#  ['14.9 oz Stella', 'Coke Zero Btl', 'Coke Zero Btl'],
#  ['20oz Water'],
#  ['Bacon Mac & Chz'],
#  ['Sprite Btl'],
#  ['Liq Tier 2 '],
#  ['20oz Water', '20oz Water', '20oz Water'],
#  ['20oz Gatorade Fr'],
#  ['Bottomless Pop'],
#  ['Small Soda', 'Small Soda', 'Hot Dog Eagles', 'Hot Dog Eagles'],
#  ['20oz Water',
#   '20oz Water',
#   'Hot Dog Eagles',
#   'Roll Cheesesteak',
#   'CP Fry Cup',
#   'CP Fry Cup'],
#  ['Roll Cheesesteak'],
#  ['Small Soda', 'Personal Pizza'],
#  ['20oz Water'],
#  ['Tortilla Chp'],
#  ['CP Fry Cup'],
#  ['Coke Bottle'],
#  ['CP Fry Cup'],
#  ['Coke Bottle'],
#  ['16oz Shock Top', '16oz Shock Top'],
#  ['Hot Dog Eagles'],
#  ['16oz Shock Top'],
#  ['Liq Tier 2 '],
#  ['CP Fry Cup'],
#  ['20oz Water'],
#  ['Pinot Grig Split', 'Pinot Grig Split'],
#  ['20oz Water'],
#  ['Small Soda'],
#  ['Domestic Draft'],
#  ['Souvenir Soda', 'Personal Pizza'],
#  ['20oz Water', '20oz Water'],
#  ['Souvenir Soda', 'CP Fry Cup'],
#  ['20oz Water'],
#  ['Small Soda'],
#  ['20oz Water'],
#  ['Small Soda'],
#  ['20oz Water'],
#  ['Liq Tier 2 '],
#  ['Margherita Pizza', 'Margherita Pizza', 'Snapple Tea', 'Diet Coke Btl'],
#  ['Cup Yard', 'Cup Frozen Drink'],
#  ['Hot Dog Eagles'],
#  ['Premium Draft'],
#  ['Liq Tier 2 '],
#  ['CP Tender Tray'],
#  ['Premium Draft', 'Premium Draft'],
#  ['Liq Tier 2 ', 'Liq Tier 2 '],
#  ['Bass Fresh Fries'],
#  ['1L Water'],
#  ['CP Fry Cup'],
#  ['20oz Water'],
#  ['Souvenir Soda', 'Souvenir Soda'],
#  ['Miller Lt Can'],
#  ['Liq Tier 2 '],
#  ['Pretzel Braided'],
#  ['20oz Water'],
#  ['Liq Tier 2 '],
#  ['CP Tender Tray'],
#  ['20oz Water'],
#  ['Small Soda'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['TL Roast Pork'],
#  ['Souvenir Soda'],
#  ['CP Small Fry', '20oz Water'],
#  ['Snapple Tea'],
#  ['Domestic Beer',
#   'Shrimp Tempura R',
#   'Roll Cheesesteak',
#   'Roll Cheesesteak',
#   'Roll Cheesesteak',
#   'Diet Coke Btl'],
#  ['Small Soda'],
#  ['Tortilla Chp'],
#  ['Small Soda', 'CP Fry Cup'],
#  ['20oz Water'],
#  ['20oz Water', '20oz Water', 'Liq Tier 2 '],
#  ['Liq Tier 2 ', 'Liq Tier 2 '],
#  ['CP Tender Tray'],
#  ['Premium Draft'],
#  ['20oz Water'],
#  ['Small Soda', 'Small Soda', '20oz Water', 'CP Fry Cup'],
#  ['Tony Luke Roll'],
#  ['Bacon Mac Burger', 'Souvenir Soda', 'Souvenir Soda'],
#  ['20oz Water', 'CP Fry Cup'],
#  ['Angus Burger'],
#  ['Cup Yard'],
#  ['Small Soda'],
#  ['16oz Shandy'],
#  ['Small Soda', 'Liq Tier 2 '],
#  ['Bass Chz Cup'],
#  ['Liq Tier 2 '],
#  ['Souvenir Soda', 'Roll Cheesesteak'],
#  ['20oz Water'],
#  ["Rita's Water Ice", "Rita's Water Ice"],
#  ['Souvenir Soda', 'CP Tender Tray', 'CP Fry Cup'],
#  ['16oz Shandy'],
#  ['Souvenir Soda', 'CP 3.25oz Cup'],
#  ['CP Tender Tray'],
#  ['Roll Cheesesteak', 'Roll Cheesesteak', 'CP Fry Cup'],
#  ['Small Soda', 'Small Soda'],
#  ['CP Fry Cup'],
#  ['16oz Shandy'],
#  ['20oz Water'],
#  ['Coke Bottle'],
#  ['Souvenir Soda'],
#  ['Small Soda', 'Souvenir Soda'],
#  ['Lein'],
#  ['French Fries', 'Hot Dog Eagles'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['20oz Water', 'Pretzel Braided'],
#  ['CP Small Fry', 'Bud Can'],
#  ['Tony Luke Roll'],
#  ['20oz Water', 'CP Tender Tray'],
#  ['Pretzel Braided'],
#  ['20oz Water'],
#  ['Bud Can'],
#  ['Small Soda', 'Tony Luke Roll', '20oz Water', 'TL Roast Pork'],
#  ['Margherita Pizza'],
#  ['CP Tender Tray', 'CP Fry Cup', 'CP 3.25oz Cup'],
#  ['Souvenir Soda'],
#  ['Liq Tier 2 ', 'Liq Tier 2 '],
#  ['Liq Tier 2 ', 'Liq Tier 2 '],
#  ['Cup Smoothie'],
#  ['Premium Draft'],
#  ['Souvenir Soda'],
#  ['20oz Water',
#   'Snapple Tea',
#   'Roll Cheesesteak',
#   'Roll Cheesesteak',
#   'CP Fry Cup'],
#  ['Angus Burger'],
#  ['CP Fry Cup'],
#  ['Hot Dog Eagles'],
#  ['1L Water'],
#  ['Pretzel Braided'],
#  ['Liq Tier 2 '],
#  ['Souvenir Soda'],
#  ['Margherita Pizza'],
#  ['Liq Tier 2 '],
#  ['Souvenir Soda'],
#  ['Liq Tier 2 '],
#  ['Tony Luke Roll'],
#  ['20oz Water', '20oz Water', 'TL Roast Pork'],
#  ['Bud Light Can', '20oz Water'],
#  ['Souvenir Soda', 'CP Fry Cup'],
#  ['Pinot Grig Split'],
#  ['Bud Light Can'],
#  ['CP Tender Tray'],
#  ['CP Fry Cup'],
#  ['20oz Water', '20oz Water', 'CP Tender Tray', 'CP Fry Cup', 'CP Fry Cup'],
#  ['Cup Yard'],
#  ['CP Fry Cup'],
#  ['Domestic Beer', 'Roll Cheesesteak'],
#  ['20oz Water'],
#  ['20oz Water', 'CP Tender Tray'],
#  ['Small Soda'],
#  ['Guinness Can'],
#  ['1L Water'],
#  ['Bottomless Pop'],
#  ['Hot Dog Eagles'],
#  ['Domestic Draft'],
#  ['CP Tender Tray'],
#  ['Domestic Draft'],
#  ['20oz Water'],
#  ['Souvenir Soda'],
#  ['Tony Luke Roll'],
#  ['Roll Cheesesteak', 'CP Fry Cup'],
#  ['Souvenir Soda', 'Snapple Tea', 'Hot Dog Eagles', 'Loop Pretzel'],
#  ['Bud Light Can', 'Liq Tier 2 ', 'Liq Tier 2 '],
#  ['16oz Shandy', '20oz Water'],
#  ['20oz Water'],
#  ['Small Soda', 'CP Fry Cup'],
#  ['Hot Dog Eagles'],
#  ['20oz Water', 'Pretzel Braided'],
#  ['Popcorn Box'],
#  ['20oz Water'],
#  ['Personal Pizza'],
#  ['Hot Dog Eagles'],
#  ['Bud Can'],
#  ['Small Soda'],
#  ['20oz Water', 'CP Fry Cup'],
#  ['20oz Water'],
#  ['Liq Tier 3 '],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['16oz Shandy'],
#  ['CP Tender Tray'],
#  ['Souvenir Soda', '20oz Water'],
#  ['Snapple Tea'],
#  ['Tony Luke Roll'],
#  ['Liq Tier 2 '],
#  ['20oz Water', '20oz Water'],
#  ['Cup Smoothie'],
#  ['CP Fry Cup'],
#  ['CP Tender Tray'],
#  ['20oz Water'],
#  ['CP Fry Cup'],
#  ['Bass Fresh Fries'],
#  ['CP Fry Cup'],
#  ['Souvenir Soda', 'CP Fry Cup'],
#  ['20oz Water'],
#  ['Souvenir Soda'],
#  ['Hot Dog Eagles'],
#  ['Souvenir Soda', 'Souvenir Soda', 'Souvenir Soda', '20oz Water'],
#  ['Topped Phl Fry', 'Plain Philly Fry', 'Pretzel Braided', 'Cheese Cup'],
#  ['Hot Dog Eagles'],
#  ['20oz Water'],
#  ['Roll Cheesesteak'],
#  ['20oz Water'],
#  ['Tony Luke Roll', 'Tony Luke Roll', 'Tony Luke Roll'],
#  ['20oz Water'],
#  ['Small Soda'],
#  ['20oz Water'],
#  ['CP Fry Cup'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['Small Soda', 'CP Buff Tenders'],
#  ['20oz Water', 'CP Fry Cup'],
#  ['Small Soda', 'CP Tender Tray'],
#  ['Bottomless Pop', 'Hot Dog Eagles', 'Loop Pretzel'],
#  ['CP Tender Tray'],
#  ['Small Soda', 'Small Soda', 'Personal Pizza'],
#  ['French Fries'],
#  ['20oz G2 LemonLim'],
#  ['CP Fry Cup'],
#  ['20oz Water'],
#  ['Hot Dog Eagles'],
#  ['Liq Tier 2 '],
#  ['Roll Cheesesteak'],
#  ['CP Tender Tray'],
#  ['2lb Tender Fd Tr'],
#  ['Roll Cheesesteak', '20oz Gatorade Fr'],
#  ['16oz Shandy'],
#  ['20oz Water', '20oz Water'],
#  ['CP Tender Tray'],
#  ['16oz Blue Moon'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['Souvenir Soda'],
#  ['Liq Tier 2 '],
#  ['CP Tender Tray'],
#  ['Personal Pizza'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['Tony Luke Roll'],
#  ['CP Small Fry'],
#  ['20oz Water', '20oz Water'],
#  ['CP Buff Tenders'],
#  ['Lein', 'Liq Tier 2 '],
#  ['Domestic Draft'],
#  ['Souvenir Soda'],
#  ['Small Soda'],
#  ['Loop Pretzel'],
#  ['Liq Tier 2 '],
#  ['Souvenir Soda'],
#  ['Shrimp Tempura R', '20oz Water'],
#  ['Miller Lt Can'],
#  ['Bass Fresh Fries'],
#  ['Premium Draft', 'Premium Draft'],
#  ['Hot Dog Eagles'],
#  ['20oz Water', 'Pretzel Braided'],
#  ['Peperoni Pizza'],
#  ['Cup Yard'],
#  ['CP Fry Cup'],
#  ['CP Tender Tray'],
#  ['Tony Luke Roll'],
#  ['CP Fry Cup'],
#  ['Small Soda', 'Small Soda'],
#  ['CP Fry Cup'],
#  ['Tony Luke Roll', 'Tony Luke Roll', '20oz Water'],
#  ['20oz Water', '20oz Water'],
#  ['CP Tender Tray'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['Souvenir Soda'],
#  ['Bass Fresh Fries'],
#  ['20oz Water'],
#  ['14.9 oz Stella', 'Mich Ultra Can'],
#  ['16oz BL Lime', 'Domestic Draft'],
#  ['Tortilla Chp', 'Popcorn Box'],
#  ['CP Tender Tray'],
#  ['Personal Pizza'],
#  ['Souvenir Draft', 'Hot Dog Eagles', 'Hot Dog Eagles'],
#  ['Loop Pretzel'],
#  ['Loop Pretzel'],
#  ['CP Fry Cup'],
#  ['Miller Lt Can'],
#  ['Lein', '20oz Water'],
#  ['Premium Draft'],
#  ['CP Fry Cup'],
#  ['Personal Pizza'],
#  ['CP Fry Cup'],
#  ['CP Fry Cup'],
#  ['CP Fry Cup'],
#  ['Personal Pizza', '20oz Water', 'Pretzel Braided'],
#  ['20oz Water', '20oz Water', 'TL Roast Pork'],
#  ['Pretzel Braided'],
#  ['20oz Water'],
#  ['20oz Water', 'Coke Bottle', 'CP Fry Cup'],
#  ['Premium Draft'],
#  ['20oz Water'],
#  ['Roll Cheesesteak', 'Roll Cheesesteak'],
#  ['Personal Pizza'],
#  ['Grill Dog'],
#  ['16oz IPA Goose', 'Hot Dog Eagles'],
#  ['Loop Pretzel'],
#  ['Roll Cheesesteak'],
#  ['Angus Burger'],
#  ['Premium Draft', 'Premium Draft'],
#  ['16oz IPA Goose'],
#  ['20oz Water'],
#  ['Cup Frozen Drink'],
#  ['CP Fry Cup'],
#  ['CP Tender Tray', 'CP Fry Cup'],
#  ['Bass Fresh Fries'],
#  ['20oz Water'],
#  ['Miller Lt Can'],
#  ['Pinot Grig Split'],
#  ['16oz BL Lime'],
#  ['Souvenir Soda', 'CP Tender Tray', 'CP Fry Cup'],
#  ['Pretzel Braided', 'CP Fry Cup'],
#  ['Bottomless Pop'],
#  ['20oz Water'],
#  ['Small Soda', 'CP Fry Cup'],
#  ['Small Soda', 'Hot Dog Eagles'],
#  ['Small Soda'],
#  ['CP Tender Tray', 'CP Fry Cup'],
#  ['Frozen Rita'],
#  ['Personal Pizza'],
#  ['Liq Tier 2 '],
#  ['CP Tender Tray'],
#  ['Liq Tier 2 '],
#  ['20oz Water'],
#  ['CP Tender Tray', 'CP Fry Cup'],
#  ['Hot Dog Eagles'],
#  ['Domestic Draft'],
#  ['Loop Pretzel'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['16oz Redds'],
#  ['20oz Water'],
#  ['20oz Water', 'Liq Tier 3 '],
#  ['20oz Water'],
#  ['Shrimp Tempura R'],
#  ['20oz Water'],
#  ['20oz Water', 'Miller Lt Can'],
#  ['Small Soda'],
#  ['20oz Water', 'CP Tender Tray'],
#  ['Small Soda', 'Personal Pizza'],
#  ['CP Small Fry'],
#  ['20oz Water'],
#  ['CP Buff Tenders', '20oz Water'],
#  ['Small Soda'],
#  ['Small Soda'],
#  ['DD Hot', 'Small Soda'],
#  ['Small Soda', '20oz Water', 'CP Tender Tray'],
#  ['Tony Luke Roll'],
#  ['Tony Luke Roll'],
#  ['CP Tender Tray'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['Hot Dog Eagles'],
#  ['Domestic Draft'],
#  ['Liq Tier 3 '],
#  ['20oz Water', 'Hot Dog Eagles', 'CP Tender Tray', 'CP Fry Cup'],
#  ['16oz Shandy'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['Mich Ultra Btl'],
#  ['Loop Pretzel'],
#  ['Personal Pizza'],
#  ['20oz G2 LemonLim'],
#  ['Bass Fresh Fries', 'Souvenir Soda'],
#  ['14.9 oz Stella'],
#  ['Small Soda'],
#  ['Domestic Draft'],
#  ['Popcorn Box'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['Chard Split'],
#  ['CP Tender Tray', 'CP Fry Cup'],
#  ['16oz Lime A Rita'],
#  ['Small Soda'],
#  ['16oz BL Lime'],
#  ['Super Premium '],
#  ['Shrimp Tempura R',
#   '20oz Water',
#   '20oz Water',
#   '20oz Water',
#   'Roll Cheesesteak'],
#  ['20oz Water', '20oz Water'],
#  ['Bud Light Can'],
#  ['20oz Water'],
#  ['Liq Tier 3 '],
#  ['Small Soda'],
#  ['16oz IPA Goose'],
#  ['Domestic Draft', 'Domestic Draft'],
#  ['20oz Water'],
#  ['2lb Tender Fd Tr', 'Souvenir Soda'],
#  ['Tony Luke Roll'],
#  ['CP Fry Cup'],
#  ['CP Fry Cup'],
#  ['BBQ Pulled Chix',
#   'BBQ Pulled Chix',
#   'Domestic Beer',
#   'Domestic Beer',
#   'Domestic Beer',
#   'LAYS CHIPS'],
#  ['CP Fry Cup'],
#  ['Souvenir Soda', 'Hot Dog Eagles'],
#  ['Hot Dog Eagles'],
#  ['Small Soda'],
#  ['Hot Dog Eagles'],
#  ['20oz Water'],
#  ['Roll Cheesesteak'],
#  ['Souvenir Soda', 'Roll Cheesesteak'],
#  ['Roll Cheesesteak'],
#  ['20oz Water'],
#  ['Souvenir Soda'],
#  ['Miller Lt Can'],
#  ['CP Fry Cup'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['Hot Dog Eagles'],
#  ['Loop Pretzel'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['Bud Light Can', 'Roll Cheesesteak'],
#  ['14.9 oz Stella'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['Snapple Half'],
#  ['2lb Tender Fd Tr', 'Souvenir Soda'],
#  ['1L Water'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['1L Water'],
#  ['1L Water'],
#  ['Mich Ultra Btl'],
#  ['20oz Water'],
#  ['Small Soda', 'Small Soda'],
#  ['Liq Tier 2 ', 'Liq Tier 2 ', 'Liq Tier 2 '],
#  ['20oz Water'],
#  ['Small Soda'],
#  ['Bud Light Can'],
#  ['CP Fry Cup'],
#  ['Margherita Pizza', '20oz Water'],
#  ['Small Soda'],
#  ['Small Soda', 'Liq Tier 3 ', 'Liq Tier 3 ', 'Liq Tier 3 ', 'Liq Tier 3 '],
#  ['CP Fry Cup'],
#  ['16oz Corona'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['1L Water'],
#  ['16oz IPA Goose'],
#  ['Small Soda'],
#  ['20oz G2 LemonLim'],
#  ['20oz Water'],
#  ['Jumbo Fries'],
#  ['20oz Water'],
#  ['Hot Dog Eagles'],
#  ['Small Soda', 'Personal Pizza'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['20oz Water', 'CP Tender Tray', 'CP Fry Cup'],
#  ['CP Fry Cup'],
#  ['Jumbo Fries'],
#  ['2lb Tender Fd Tr'],
#  ['CP Fry Cup'],
#  ['CP Fry Cup'],
#  ['20oz Water'],
#  ['Small Soda'],
#  ['16oz Yuengling'],
#  ['Miller Lt Can'],
#  ['20oz Water'],
#  ['Loop Pretzel'],
#  ['20oz Water'],
#  ['CP Tender Tray'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['Cup Yard'],
#  ['Bass Fresh Fries'],
#  ['20oz Water'],
#  ['Loop Pretzel'],
#  ['20oz Water'],
#  ['Roll Cheesesteak'],
#  ['Small Soda'],
#  ['Tortilla Chp'],
#  ['Pretzel Braided'],
#  ['Souvenir Soda', 'Roll Cheesesteak'],
#  ['14.9 oz Stella'],
#  ['Liq Tier 2 '],
#  ['Goose Island', '16oz BL Lime'],
#  ['20oz Water'],
#  ['CP Fry Cup'],
#  ['1L Water'],
#  ['Angus Burger', 'French Fries'],
#  ['Souvenir Soda'],
#  ['20oz Water', 'CP Fry Cup'],
#  ['Cup Smoothie'],
#  ['CP Fry Cup'],
#  ['Souvenir Soda'],
#  ['Loop Pretzel'],
#  ['Hot Dog Eagles'],
#  ['20oz Water', 'CP Tender Tray', 'CP Tender Tray'],
#  ['CP 3.25oz Cup'],
#  ['20oz Water', 'Pretzel Braided'],
#  ['20oz Water'],
#  ['Small Soda', '20oz Water', 'Liq Tier 2 ', 'Liq Tier 2 '],
#  ['16oz Corona', '16oz Corona', '16oz Corona', 'Liq Tier 2 '],
#  ['CP Fry Cup'],
#  ['20oz Water', '20oz Water'],
#  ['20oz Water'],
#  ['20oz Water', '20oz Water', 'CP Fry Cup'],
#  ['20oz Water', 'CP Fry Cup'],
#  ['20oz Water'],
#  ['20oz Water', '20oz Water', '20oz Water'],
#  ['CP Fry Cup'],
#  ['Small Soda', 'CP Tender Tray'],
#  ['Liq Tier 2 '],
#  ['20oz Water', 'CP Tender Tray'],
#  ['20oz Water'],
#  ['20oz Water', 'Sprite Btl', 'CP Fry Cup'],
#  ['Roll Cheesesteak', 'CP Fry Cup'],
#  ['Small Soda', '20oz Water'],
#  ['Premium Draft', 'Premium Draft', '20oz Water'],
#  ['Mich Ultra Btl'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['Personal Pizza'],
#  ['Cup Yard', 'Cup Yard'],
#  ['Cup Yard'],
#  ['CP Tender Tray'],
#  ['1L Water'],
#  ['Small Soda', 'CP Tender Tray'],
#  ['CP Fry Cup'],
#  ['14.9 oz Stella'],
#  ['Cup Frozen Drink'],
#  ['16oz Lime A Rita'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['CP Fry Cup'],
#  ['Domestic Beer'],
#  ['CP Tender Tray'],
#  ['Premium Draft'],
#  ['Souvenir Soda'],
#  ['Small Soda', 'Roll Cheesesteak'],
#  ['CP Fry Cup'],
#  ['Snap Diet Peach'],
#  ['Small Soda', 'CP Fry Cup'],
#  ['20oz Water', '20oz Water'],
#  ['16oz Sierra Nev', 'Bud Light Can'],
#  ['20oz Water'],
#  ['Domestic Beer'],
#  ['CP Fry Cup'],
#  ['16oz Redds'],
#  ['Roll Cheesesteak', 'CP Fry Cup'],
#  ['14.9 oz Stella', 'Mich Ultra Btl'],
#  ['Chard Split'],
#  ['CP Fry Cup'],
#  ['16oz IPA Goose'],
#  ['Cup Yard', '20oz Water', 'Pretzel Braided'],
#  ['20oz Water'],
#  ['CP Fry Cup'],
#  ['Roll Cheesesteak'],
#  ['CP Tender Tray'],
#  ['Souvenir Soda'],
#  ['Souvenir Soda'],
#  ['Domestic Beer'],
#  ['CP Fry Cup'],
#  ['20oz Water'],
#  ['Jumbo Fries',
#   '2lb Tender Fd Tr',
#   '2lb Tender Fd Tr',
#   'French Fries',
#   '20oz Water',
#   '20oz Water',
#   '20oz Water',
#   'Hot Dog Eagles'],
#  ['CP Fry Cup'],
#  ['20oz Water'],
#  ['16oz Corona'],
#  ['14.9 oz Stella', '20oz Water', '20oz Water', '20oz Water'],
#  ['Small Soda', 'Tony Luke Roll'],
#  ['Domestic Draft'],
#  ['20oz Water'],
#  ['CP Tender Tray', 'CP Fry Cup'],
#  ['Popcorn Box'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['Plain Philly Fry'],
#  ['CP Fry Cup'],
#  ['Bud Can', 'Snap Diet Peach'],
#  ['20oz Water'],
#  ['Bass Fresh Fries'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['CP 3.25oz Cup'],
#  ['Liq Tier 3 '],
#  ['Crispin Can'],
#  ['14.9 oz Stella', 'Liq Tier 2 '],
#  ['CP 3.25oz Cup'],
#  ['Coke Bottle'],
#  ['Mikes Cran'],
#  ['20oz Water'],
#  ['Small Soda'],
#  ['Hot Dog Eagles'],
#  ['Small Soda'],
#  ['20oz Water'],
#  ['Pretzel Braided'],
#  ['20oz Water'],
#  ['Domestic Draft', 'Domestic Draft', 'Roll Cheesesteak', 'Roll Cheesesteak'],
#  ['Liq Tier 3 ', 'Liq Tier 3 ', 'Liq Tier 3 ', 'Liq Tier 3 '],
#  ['Hot Dog Eagles'],
#  ['Miller Lt Can'],
#  ['20oz Water'],
#  ['20oz Gatorade Fr'],
#  ['Miller Lt Can'],
#  ['Grill Dog'],
#  ['CP Small Fry', 'Personal Pizza'],
#  ['CP Fry Cup'],
#  ['16oz Yuengling'],
#  ['Loop Pretzel'],
#  ['Roll Cheesesteak'],
#  ['20oz Water'],
#  ['Personal Pizza'],
#  ['20oz Water'],
#  ['Small Soda'],
#  ['20oz Water'],
#  ['20oz Water', 'CP Fry Cup'],
#  ['20oz Water'],
#  ['Liq Tier 2 ', 'Liq Tier 2 '],
#  ['Bud Light Can'],
#  ['CP Fry Cup'],
#  ['Roll Cheesesteak'],
#  ['Small Soda'],
#  ['Snapple Tea'],
#  ['Domestic Beer'],
#  ['Liq Tier 2 '],
#  ['Coke Bottle', 'Coke Bottle'],
#  ['Diet Coke Btl'],
#  ['20oz Water', 'CP Tender Tray', 'CP Fry Cup'],
#  ['TL Roast Pork'],
#  ['20oz Water'],
#  ['Liq Tier 2 '],
#  ['Bud Light Can'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['Domestic Beer', 'IC Sundae '],
#  ['16oz IPA Goose', 'Personal Pizza'],
#  ['CP Buff Tenders', 'CP Buff Tenders', 'CP Fry Cup'],
#  ['Guinness Can'],
#  ['CP Fry Cup'],
#  ['20oz G2 LemonLim'],
#  ['Pretzel Braided'],
#  ['20oz G2 LemonLim'],
#  ['16oz Shandy'],
#  ['20oz Water'],
#  ['CP Fry Cup'],
#  ['CP Tender Tray'],
#  ['Coors Light'],
#  ['Small Soda'],
#  ['Hot Dog Eagles'],
#  ['Souvenir Soda', 'CP Tender Tray', 'CP Fry Cup'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ['20oz Water', 'Cup Frozen Drink', 'Domestic Draft', 'Domestic Draft'],
#  ['Grill Dog'],
#  ['Lein'],
#  ['Coke Bottle'],
#  ['20oz Water'],
#  ['Liq Tier 2 ', 'Liq Tier 2 '],
#  ['CP Fry Cup'],
#  ['Premium Draft', '20oz Water'],
#  ['CP Tender Tray'],
#  ['20oz Water'],
#  ['20oz Water'],
#  ...]

# %%
len(allBaskets)
# Out:
# 3138976

# %% [markdown]
# ### Run the A Priori Algorithm to find frequent itemsets of 1 to 3. A Priori uses a triangular matrix approach. Itemsets are built off of previously determined itemsets.

# %%
from itertools import combinations
def apriori(groceryBaskets, support=0.01):
    """Return a dictionary of itemsets that are frequent.
    
    Keys in the returned dictionary are itemsets; 
    values are corresponding support fractions.
    
    datastream: CSV file with market basket data
    support: threshold
    """
    freqItemsets = defaultdict(dict)
    i = 0
    while True:
        i += 1
        count = defaultdict(int)
        for basket in groceryBaskets:
            if i==1:
                items = basket
            else:
                items = [item for item in basket 
                         if frozenset([item]) in freqItemsets[1]]
            for group in combinations(items, i):
                for subgroup in combinations(group, i-1):
                    if frozenset(subgroup) not in freqItemsets[i-1]:
                        break
                # found a candidate group of items!
                count[frozenset(list(group))] += 1
        for g in count:
            freq = count[g]/len(groceryBaskets)
            if freq >= support:
                freqItemsets[i][g] = freq
        msg = "Frequent itemsets of size {0} at support threshold {1} = {2}"
        print(msg.format(i, support, len(freqItemsets[i])))
        if len(freqItemsets[i]) == 0:
            try:
                del freqItemsets[i]
            except KeyError as err:
                pass
            break
        elif  i == 3:
            break
    return freqItemsets

# %%
from collections import defaultdict
import random

# %% [markdown]
# ### Finds frequent itemsets for all the data.

# %%
freqsets = apriori(allBaskets, 0.01)
# Out:
# Frequent itemsets of size 1 at support threshold 0.01 = 38
# Frequent itemsets of size 2 at support threshold 0.01 = 3
# Frequent itemsets of size 3 at support threshold 0.01 = 1

# %% [markdown]
# ### Plot the top twenty frequent items that represent the entire data.

# %%
import matplotlib.pyplot as plt

def plotTopTwenty(groceryBaskets, support=0.01):
    """Make an inline plot of the top twenty most frequent items
    
    datafile: CSV file with market basket data
    support: threshold
    """
    freqSingle = {}
    numBaskets = 0
    items = []
    
    for basket in groceryBaskets:
        for item in basket:
            if item in freqSingle:
                freqSingle[item] += 1
            else:
                freqSingle[item] = 1
        numBaskets +=1
    
    # Keep only frequent items
    freqSingle = {key: value for key, value in freqSingle.items() if (value/numBaskets) >= support}
    
    # Plotting
    for key in freqSingle:
        items.append([key, freqSingle[key]])
    
    items.sort(key=lambda x: x[1], reverse = True)
    x = [items[i][0] for i in range(20)]
    y = [items[i][1] for i in range(20)]
    
    fig = plt.figure()

    width = .5
    ind = np.arange(20)
    plt.bar(ind, y, width=width)
    plt.xticks(ind + width / 2, x, rotation = 'vertical')
    plt.xlabel('Top 20 Frequent Items')
    plt.ylabel('Frequencies')
    plt.show()

# %%
plotTopTwenty(allBaskets)

# %% [markdown]
# ** Frequent pairs of the entire dataset.**

# %%
freqsets[2]
# Out:
# {frozenset({'BTL DASANI'}): 0.010901962933134883,
#  frozenset({'$1.00 DOG '}): 0.017510806071789016,
#  frozenset({'FRIED ONIONS', 'TONY L STEAK'}): 0.010463603417165342}

# %% [markdown]
# ### Find frequent itemsets per location for all Locations if available.
# - Put all menu items into respective baskets.
#
# - Then generate hash tables for the frequent itemsets of sizes 1 to 3 per Location.
#
# - Put all hash tables into one hash table.

# %%
def generateMarketChunks(chunk):
    masterMenuList = list()
    m_faqs = chunk.merge(menu)
    basketList = m_faqs.groupby('guestCheckID')['menuItemName1'].apply(list)
    for basket in basketList:
        masterMenuList.append(basket)
    return masterMenuList

# %%
def generateLocFreqs(df):
    locFreqs = defaultdict(dict)
    for loc in df.Location.unique():
        locFreqs[loc] = apriori(generateMarketChunks(df[df.Location == loc]), 0.01)
        #print("Success")
    return locFreqs

# %%
def generateIndMarket(bigdf):
    masterLocs = dict()
    for chunk in bigdf:
        masterLocs.update(generateLocFreqs(chunk))
    return masterLocs

# %%
locfreqs = generateLocFreqs(df)
# Out:
# Frequent itemsets of size 1 at support threshold 0.01 = 29
# Frequent itemsets of size 2 at support threshold 0.01 = 13
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 28
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 28
# Frequent itemsets of size 2 at support threshold 0.01 = 10
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 34
# Frequent itemsets of size 2 at support threshold 0.01 = 12
# Frequent itemsets of size 3 at support threshold 0.01 = 3
# Frequent itemsets of size 1 at support threshold 0.01 = 27
# Frequent itemsets of size 2 at support threshold 0.01 = 12
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 16
# Frequent itemsets of size 2 at support threshold 0.01 = 12
# Frequent itemsets of size 3 at support threshold 0.01 = 6
# Frequent itemsets of size 1 at support threshold 0.01 = 19
# Frequent itemsets of size 2 at support threshold 0.01 = 1
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 41
# Frequent itemsets of size 2 at support threshold 0.01 = 19
# Frequent itemsets of size 3 at support threshold 0.01 = 3
# Frequent itemsets of size 1 at support threshold 0.01 = 20
# Frequent itemsets of size 2 at support threshold 0.01 = 14
# Frequent itemsets of size 3 at support threshold 0.01 = 5
# Frequent itemsets of size 1 at support threshold 0.01 = 24
# Frequent itemsets of size 2 at support threshold 0.01 = 3
# Frequent itemsets of size 3 at support threshold 0.01 = 3
# Frequent itemsets of size 1 at support threshold 0.01 = 33
# Frequent itemsets of size 2 at support threshold 0.01 = 22
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 34
# Frequent itemsets of size 2 at support threshold 0.01 = 17
# Frequent itemsets of size 3 at support threshold 0.01 = 13
# Frequent itemsets of size 1 at support threshold 0.01 = 27
# Frequent itemsets of size 2 at support threshold 0.01 = 15
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 22
# Frequent itemsets of size 2 at support threshold 0.01 = 18
# Frequent itemsets of size 3 at support threshold 0.01 = 9
# Frequent itemsets of size 1 at support threshold 0.01 = 29
# Frequent itemsets of size 2 at support threshold 0.01 = 17
# Frequent itemsets of size 3 at support threshold 0.01 = 5
# Frequent itemsets of size 1 at support threshold 0.01 = 24
# Frequent itemsets of size 2 at support threshold 0.01 = 2
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 31
# Frequent itemsets of size 2 at support threshold 0.01 = 17
# Frequent itemsets of size 3 at support threshold 0.01 = 4
# Frequent itemsets of size 1 at support threshold 0.01 = 14
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 9
# Frequent itemsets of size 2 at support threshold 0.01 = 7
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 28
# Frequent itemsets of size 2 at support threshold 0.01 = 19
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 31
# Frequent itemsets of size 2 at support threshold 0.01 = 9
# Frequent itemsets of size 3 at support threshold 0.01 = 10
# Frequent itemsets of size 1 at support threshold 0.01 = 20
# Frequent itemsets of size 2 at support threshold 0.01 = 12
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 28
# Frequent itemsets of size 2 at support threshold 0.01 = 11
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 27
# Frequent itemsets of size 2 at support threshold 0.01 = 15
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 22
# Frequent itemsets of size 2 at support threshold 0.01 = 9
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 31
# Frequent itemsets of size 2 at support threshold 0.01 = 14
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 27
# Frequent itemsets of size 2 at support threshold 0.01 = 16
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 27
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 28
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 30
# Frequent itemsets of size 2 at support threshold 0.01 = 9
# Frequent itemsets of size 3 at support threshold 0.01 = 5
# Frequent itemsets of size 1 at support threshold 0.01 = 25
# Frequent itemsets of size 2 at support threshold 0.01 = 14
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 28
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 21
# Frequent itemsets of size 2 at support threshold 0.01 = 7
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 20
# Frequent itemsets of size 2 at support threshold 0.01 = 10
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 19
# Frequent itemsets of size 2 at support threshold 0.01 = 10
# Frequent itemsets of size 3 at support threshold 0.01 = 3
# Frequent itemsets of size 1 at support threshold 0.01 = 11
# Frequent itemsets of size 2 at support threshold 0.01 = 8
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 28
# Frequent itemsets of size 2 at support threshold 0.01 = 14
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 31
# Frequent itemsets of size 2 at support threshold 0.01 = 15
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 30
# Frequent itemsets of size 2 at support threshold 0.01 = 24
# Frequent itemsets of size 3 at support threshold 0.01 = 4
# Frequent itemsets of size 1 at support threshold 0.01 = 28
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 5
# Frequent itemsets of size 1 at support threshold 0.01 = 19
# Frequent itemsets of size 2 at support threshold 0.01 = 7
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 30
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 356
# Frequent itemsets of size 2 at support threshold 0.01 = 318
# Frequent itemsets of size 3 at support threshold 0.01 = 2166
# Frequent itemsets of size 1 at support threshold 0.01 = 23
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 5
# Frequent itemsets of size 1 at support threshold 0.01 = 28
# Frequent itemsets of size 2 at support threshold 0.01 = 18
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 24
# Frequent itemsets of size 2 at support threshold 0.01 = 7
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 30
# Frequent itemsets of size 2 at support threshold 0.01 = 19
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 20
# Frequent itemsets of size 2 at support threshold 0.01 = 2
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 15
# Frequent itemsets of size 2 at support threshold 0.01 = 1
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 22
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 32
# Frequent itemsets of size 2 at support threshold 0.01 = 20
# Frequent itemsets of size 3 at support threshold 0.01 = 5
# Frequent itemsets of size 1 at support threshold 0.01 = 24
# Frequent itemsets of size 2 at support threshold 0.01 = 10
# Frequent itemsets of size 3 at support threshold 0.01 = 6
# Frequent itemsets of size 1 at support threshold 0.01 = 17
# Frequent itemsets of size 2 at support threshold 0.01 = 13
# Frequent itemsets of size 3 at support threshold 0.01 = 5
# Frequent itemsets of size 1 at support threshold 0.01 = 29
# Frequent itemsets of size 2 at support threshold 0.01 = 15
# Frequent itemsets of size 3 at support threshold 0.01 = 3
# Frequent itemsets of size 1 at support threshold 0.01 = 18
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 23
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 43
# Frequent itemsets of size 2 at support threshold 0.01 = 13
# Frequent itemsets of size 3 at support threshold 0.01 = 10
# Frequent itemsets of size 1 at support threshold 0.01 = 29
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 17
# Frequent itemsets of size 2 at support threshold 0.01 = 12
# Frequent itemsets of size 3 at support threshold 0.01 = 5
# Frequent itemsets of size 1 at support threshold 0.01 = 14
# Frequent itemsets of size 2 at support threshold 0.01 = 3
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 15
# Frequent itemsets of size 2 at support threshold 0.01 = 10
# Frequent itemsets of size 3 at support threshold 0.01 = 5
# Frequent itemsets of size 1 at support threshold 0.01 = 16
# Frequent itemsets of size 2 at support threshold 0.01 = 2
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 21
# Frequent itemsets of size 2 at support threshold 0.01 = 12
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 20
# Frequent itemsets of size 2 at support threshold 0.01 = 13
# Frequent itemsets of size 3 at support threshold 0.01 = 3
# Frequent itemsets of size 1 at support threshold 0.01 = 28
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 11
# Frequent itemsets of size 2 at support threshold 0.01 = 3
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 35
# Frequent itemsets of size 2 at support threshold 0.01 = 11
# Frequent itemsets of size 3 at support threshold 0.01 = 22
# Frequent itemsets of size 1 at support threshold 0.01 = 23
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 26
# Frequent itemsets of size 2 at support threshold 0.01 = 13
# Frequent itemsets of size 3 at support threshold 0.01 = 10
# Frequent itemsets of size 1 at support threshold 0.01 = 20
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 21
# Frequent itemsets of size 2 at support threshold 0.01 = 13
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 17
# Frequent itemsets of size 2 at support threshold 0.01 = 3
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 24
# Frequent itemsets of size 2 at support threshold 0.01 = 12
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 13
# Frequent itemsets of size 2 at support threshold 0.01 = 3
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 13
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 16
# Frequent itemsets of size 2 at support threshold 0.01 = 10
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 20
# Frequent itemsets of size 2 at support threshold 0.01 = 7
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 12
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 27
# Frequent itemsets of size 2 at support threshold 0.01 = 18
# Frequent itemsets of size 3 at support threshold 0.01 = 3
# Frequent itemsets of size 1 at support threshold 0.01 = 7
# Frequent itemsets of size 2 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 14
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 15
# Frequent itemsets of size 2 at support threshold 0.01 = 10
# Frequent itemsets of size 3 at support threshold 0.01 = 9
# Frequent itemsets of size 1 at support threshold 0.01 = 32
# Frequent itemsets of size 2 at support threshold 0.01 = 24
# Frequent itemsets of size 3 at support threshold 0.01 = 23
# Frequent itemsets of size 1 at support threshold 0.01 = 19
# Frequent itemsets of size 2 at support threshold 0.01 = 8
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 11
# Frequent itemsets of size 2 at support threshold 0.01 = 1
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 9
# Frequent itemsets of size 2 at support threshold 0.01 = 7
# Frequent itemsets of size 3 at support threshold 0.01 = 5
# Frequent itemsets of size 1 at support threshold 0.01 = 18
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 3
# Frequent itemsets of size 1 at support threshold 0.01 = 1
# Frequent itemsets of size 2 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 20
# Frequent itemsets of size 2 at support threshold 0.01 = 9
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 12
# Frequent itemsets of size 2 at support threshold 0.01 = 3
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 4
# Frequent itemsets of size 2 at support threshold 0.01 = 0

# %%
fact = pd.read_csv('../data/FACT_Sites_2017.csv', parse_dates=True,
                   na_values='NULL', chunksize=100000, iterator=True,
                       
                      usecols=['Location', 'guestCheckID', 'recordID'])

# %%
locFreqDict = generateIndMarket(fact)
# Out:
# Frequent itemsets of size 1 at support threshold 0.01 = 17
# Frequent itemsets of size 2 at support threshold 0.01 = 13
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 25
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 20
# Frequent itemsets of size 2 at support threshold 0.01 = 10
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 25
# Frequent itemsets of size 2 at support threshold 0.01 = 12
# Frequent itemsets of size 3 at support threshold 0.01 = 3
# Frequent itemsets of size 1 at support threshold 0.01 = 17
# Frequent itemsets of size 2 at support threshold 0.01 = 12
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 8
# Frequent itemsets of size 2 at support threshold 0.01 = 12
# Frequent itemsets of size 3 at support threshold 0.01 = 6
# Frequent itemsets of size 1 at support threshold 0.01 = 19
# Frequent itemsets of size 2 at support threshold 0.01 = 1
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 23
# Frequent itemsets of size 2 at support threshold 0.01 = 19
# Frequent itemsets of size 3 at support threshold 0.01 = 3
# Frequent itemsets of size 1 at support threshold 0.01 = 9
# Frequent itemsets of size 2 at support threshold 0.01 = 14
# Frequent itemsets of size 3 at support threshold 0.01 = 5
# Frequent itemsets of size 1 at support threshold 0.01 = 23
# Frequent itemsets of size 2 at support threshold 0.01 = 3
# Frequent itemsets of size 3 at support threshold 0.01 = 3
# Frequent itemsets of size 1 at support threshold 0.01 = 15
# Frequent itemsets of size 2 at support threshold 0.01 = 22
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 22
# Frequent itemsets of size 2 at support threshold 0.01 = 17
# Frequent itemsets of size 3 at support threshold 0.01 = 13
# Frequent itemsets of size 1 at support threshold 0.01 = 13
# Frequent itemsets of size 2 at support threshold 0.01 = 15
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 9
# Frequent itemsets of size 2 at support threshold 0.01 = 18
# Frequent itemsets of size 3 at support threshold 0.01 = 9
# Frequent itemsets of size 1 at support threshold 0.01 = 14
# Frequent itemsets of size 2 at support threshold 0.01 = 17
# Frequent itemsets of size 3 at support threshold 0.01 = 5
# Frequent itemsets of size 1 at support threshold 0.01 = 23
# Frequent itemsets of size 2 at support threshold 0.01 = 2
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 17
# Frequent itemsets of size 2 at support threshold 0.01 = 17
# Frequent itemsets of size 3 at support threshold 0.01 = 4
# Frequent itemsets of size 1 at support threshold 0.01 = 8
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 5
# Frequent itemsets of size 2 at support threshold 0.01 = 7
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 13
# Frequent itemsets of size 2 at support threshold 0.01 = 19
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 24
# Frequent itemsets of size 2 at support threshold 0.01 = 9
# Frequent itemsets of size 3 at support threshold 0.01 = 10
# Frequent itemsets of size 1 at support threshold 0.01 = 10
# Frequent itemsets of size 2 at support threshold 0.01 = 12
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 21
# Frequent itemsets of size 2 at support threshold 0.01 = 11
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 17
# Frequent itemsets of size 2 at support threshold 0.01 = 15
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 14
# Frequent itemsets of size 2 at support threshold 0.01 = 9
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 20
# Frequent itemsets of size 2 at support threshold 0.01 = 14
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 15
# Frequent itemsets of size 2 at support threshold 0.01 = 16
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 23
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 20
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 27
# Frequent itemsets of size 2 at support threshold 0.01 = 9
# Frequent itemsets of size 3 at support threshold 0.01 = 5
# Frequent itemsets of size 1 at support threshold 0.01 = 12
# Frequent itemsets of size 2 at support threshold 0.01 = 14
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 23
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 17
# Frequent itemsets of size 2 at support threshold 0.01 = 7
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 11
# Frequent itemsets of size 2 at support threshold 0.01 = 10
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 10
# Frequent itemsets of size 2 at support threshold 0.01 = 10
# Frequent itemsets of size 3 at support threshold 0.01 = 3
# Frequent itemsets of size 1 at support threshold 0.01 = 6
# Frequent itemsets of size 2 at support threshold 0.01 = 8
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 17
# Frequent itemsets of size 2 at support threshold 0.01 = 14
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 19
# Frequent itemsets of size 2 at support threshold 0.01 = 15
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 12
# Frequent itemsets of size 2 at support threshold 0.01 = 24
# Frequent itemsets of size 3 at support threshold 0.01 = 4
# Frequent itemsets of size 1 at support threshold 0.01 = 26
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 5
# Frequent itemsets of size 1 at support threshold 0.01 = 14
# Frequent itemsets of size 2 at support threshold 0.01 = 7
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 27
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 30
# Frequent itemsets of size 2 at support threshold 0.01 = 318
# Frequent itemsets of size 3 at support threshold 0.01 = 2166
# Frequent itemsets of size 1 at support threshold 0.01 = 21
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 5
# Frequent itemsets of size 1 at support threshold 0.01 = 13
# Frequent itemsets of size 2 at support threshold 0.01 = 18
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 18
# Frequent itemsets of size 2 at support threshold 0.01 = 7
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 13
# Frequent itemsets of size 2 at support threshold 0.01 = 19
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 18
# Frequent itemsets of size 2 at support threshold 0.01 = 2
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 14
# Frequent itemsets of size 2 at support threshold 0.01 = 1
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 17
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 17
# Frequent itemsets of size 2 at support threshold 0.01 = 20
# Frequent itemsets of size 3 at support threshold 0.01 = 5
# Frequent itemsets of size 1 at support threshold 0.01 = 17
# Frequent itemsets of size 2 at support threshold 0.01 = 10
# Frequent itemsets of size 3 at support threshold 0.01 = 6
# Frequent itemsets of size 1 at support threshold 0.01 = 10
# Frequent itemsets of size 2 at support threshold 0.01 = 13
# Frequent itemsets of size 3 at support threshold 0.01 = 5
# Frequent itemsets of size 1 at support threshold 0.01 = 17
# Frequent itemsets of size 2 at support threshold 0.01 = 15
# Frequent itemsets of size 3 at support threshold 0.01 = 3
# Frequent itemsets of size 1 at support threshold 0.01 = 14
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 19
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 31
# Frequent itemsets of size 2 at support threshold 0.01 = 13
# Frequent itemsets of size 3 at support threshold 0.01 = 10
# Frequent itemsets of size 1 at support threshold 0.01 = 27
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 9
# Frequent itemsets of size 2 at support threshold 0.01 = 12
# Frequent itemsets of size 3 at support threshold 0.01 = 5
# Frequent itemsets of size 1 at support threshold 0.01 = 13
# Frequent itemsets of size 2 at support threshold 0.01 = 3
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 8
# Frequent itemsets of size 2 at support threshold 0.01 = 10
# Frequent itemsets of size 3 at support threshold 0.01 = 5
# Frequent itemsets of size 1 at support threshold 0.01 = 15
# Frequent itemsets of size 2 at support threshold 0.01 = 2
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 13
# Frequent itemsets of size 2 at support threshold 0.01 = 12
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 13
# Frequent itemsets of size 2 at support threshold 0.01 = 13
# Frequent itemsets of size 3 at support threshold 0.01 = 3
# Frequent itemsets of size 1 at support threshold 0.01 = 25
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 9
# Frequent itemsets of size 2 at support threshold 0.01 = 3
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 28
# Frequent itemsets of size 2 at support threshold 0.01 = 11
# Frequent itemsets of size 3 at support threshold 0.01 = 22
# Frequent itemsets of size 1 at support threshold 0.01 = 17
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 18
# Frequent itemsets of size 2 at support threshold 0.01 = 13
# Frequent itemsets of size 3 at support threshold 0.01 = 10
# Frequent itemsets of size 1 at support threshold 0.01 = 17
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 9
# Frequent itemsets of size 2 at support threshold 0.01 = 13
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 16
# Frequent itemsets of size 2 at support threshold 0.01 = 3
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 17
# Frequent itemsets of size 2 at support threshold 0.01 = 12
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 13
# Frequent itemsets of size 2 at support threshold 0.01 = 3
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 8
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 8
# Frequent itemsets of size 2 at support threshold 0.01 = 10
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 15
# Frequent itemsets of size 2 at support threshold 0.01 = 7
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 11
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 14
# Frequent itemsets of size 2 at support threshold 0.01 = 18
# Frequent itemsets of size 3 at support threshold 0.01 = 3
# Frequent itemsets of size 1 at support threshold 0.01 = 7
# Frequent itemsets of size 2 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 10
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 7
# Frequent itemsets of size 2 at support threshold 0.01 = 10
# Frequent itemsets of size 3 at support threshold 0.01 = 9
# Frequent itemsets of size 1 at support threshold 0.01 = 15
# Frequent itemsets of size 2 at support threshold 0.01 = 24
# Frequent itemsets of size 3 at support threshold 0.01 = 23
# Frequent itemsets of size 1 at support threshold 0.01 = 14
# Frequent itemsets of size 2 at support threshold 0.01 = 8
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 10
# Frequent itemsets of size 2 at support threshold 0.01 = 1
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 5
# Frequent itemsets of size 2 at support threshold 0.01 = 7
# Frequent itemsets of size 3 at support threshold 0.01 = 5
# Frequent itemsets of size 1 at support threshold 0.01 = 15
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 3
# Frequent itemsets of size 1 at support threshold 0.01 = 1
# Frequent itemsets of size 2 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 16
# Frequent itemsets of size 2 at support threshold 0.01 = 9
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 10
# Frequent itemsets of size 2 at support threshold 0.01 = 3
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 4
# Frequent itemsets of size 2 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 25
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 8
# Frequent itemsets of size 2 at support threshold 0.01 = 1
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 21
# Frequent itemsets of size 2 at support threshold 0.01 = 10
# Frequent itemsets of size 3 at support threshold 0.01 = 3
# Frequent itemsets of size 1 at support threshold 0.01 = 9
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 19
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 12
# Frequent itemsets of size 2 at support threshold 0.01 = 9
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 16
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 18
# Frequent itemsets of size 2 at support threshold 0.01 = 7
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 26
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 20
# Frequent itemsets of size 2 at support threshold 0.01 = 1
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 12
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 19
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 19
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 24
# Frequent itemsets of size 2 at support threshold 0.01 = 9
# Frequent itemsets of size 3 at support threshold 0.01 = 11
# Frequent itemsets of size 1 at support threshold 0.01 = 14
# Frequent itemsets of size 2 at support threshold 0.01 = 10
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 17
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 16
# Frequent itemsets of size 2 at support threshold 0.01 = 2
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 9
# Frequent itemsets of size 2 at support threshold 0.01 = 7
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 23
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 9
# Frequent itemsets of size 2 at support threshold 0.01 = 14
# Frequent itemsets of size 3 at support threshold 0.01 = 6
# Frequent itemsets of size 1 at support threshold 0.01 = 16
# Frequent itemsets of size 2 at support threshold 0.01 = 13
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 15
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 9
# Frequent itemsets of size 2 at support threshold 0.01 = 10
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 28
# Frequent itemsets of size 2 at support threshold 0.01 = 7
# Frequent itemsets of size 3 at support threshold 0.01 = 13
# Frequent itemsets of size 1 at support threshold 0.01 = 14
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 19
# Frequent itemsets of size 2 at support threshold 0.01 = 3
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 13
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 15
# Frequent itemsets of size 2 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 14
# Frequent itemsets of size 2 at support threshold 0.01 = 3
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 11
# Frequent itemsets of size 2 at support threshold 0.01 = 7
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 24
# Frequent itemsets of size 2 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 20
# Frequent itemsets of size 2 at support threshold 0.01 = 9
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 26
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 14
# Frequent itemsets of size 2 at support threshold 0.01 = 14
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 15
# Frequent itemsets of size 2 at support threshold 0.01 = 1
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 8
# Frequent itemsets of size 2 at support threshold 0.01 = 9
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 16
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 24
# Frequent itemsets of size 2 at support threshold 0.01 = 2
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 22
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 25
# Frequent itemsets of size 2 at support threshold 0.01 = 2
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 17
# Frequent itemsets of size 2 at support threshold 0.01 = 1
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 17
# Frequent itemsets of size 2 at support threshold 0.01 = 1
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 24
# Frequent itemsets of size 2 at support threshold 0.01 = 1
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 25
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 15
# Frequent itemsets of size 2 at support threshold 0.01 = 12
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 24
# Frequent itemsets of size 2 at support threshold 0.01 = 2
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 12
# Frequent itemsets of size 2 at support threshold 0.01 = 8
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 29
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 12
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 19
# Frequent itemsets of size 2 at support threshold 0.01 = 2
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 10
# Frequent itemsets of size 2 at support threshold 0.01 = 9
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 17
# Frequent itemsets of size 2 at support threshold 0.01 = 10
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 19
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 18
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 25
# Frequent itemsets of size 2 at support threshold 0.01 = 11
# Frequent itemsets of size 3 at support threshold 0.01 = 4
# Frequent itemsets of size 1 at support threshold 0.01 = 12
# Frequent itemsets of size 2 at support threshold 0.01 = 10
# Frequent itemsets of size 3 at support threshold 0.01 = 3
# Frequent itemsets of size 1 at support threshold 0.01 = 9
# Frequent itemsets of size 2 at support threshold 0.01 = 14
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 12
# Frequent itemsets of size 2 at support threshold 0.01 = 9
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 17
# Frequent itemsets of size 2 at support threshold 0.01 = 7
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 17
# Frequent itemsets of size 2 at support threshold 0.01 = 8
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 21
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 14
# Frequent itemsets of size 2 at support threshold 0.01 = 7
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 14
# Frequent itemsets of size 2 at support threshold 0.01 = 17
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 17
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 13
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 28
# Frequent itemsets of size 2 at support threshold 0.01 = 7
# Frequent itemsets of size 3 at support threshold 0.01 = 3
# Frequent itemsets of size 1 at support threshold 0.01 = 12
# Frequent itemsets of size 2 at support threshold 0.01 = 18
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 13
# Frequent itemsets of size 2 at support threshold 0.01 = 7
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 11
# Frequent itemsets of size 2 at support threshold 0.01 = 8
# Frequent itemsets of size 3 at support threshold 0.01 = 3
# Frequent itemsets of size 1 at support threshold 0.01 = 31
# Frequent itemsets of size 2 at support threshold 0.01 = 306
# Frequent itemsets of size 3 at support threshold 0.01 = 1839
# Frequent itemsets of size 1 at support threshold 0.01 = 5
# Frequent itemsets of size 2 at support threshold 0.01 = 9
# Frequent itemsets of size 3 at support threshold 0.01 = 11
# Frequent itemsets of size 1 at support threshold 0.01 = 19
# Frequent itemsets of size 2 at support threshold 0.01 = 1
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 14
# Frequent itemsets of size 2 at support threshold 0.01 = 2
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 17
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 8
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 18
# Frequent itemsets of size 2 at support threshold 0.01 = 13
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 10
# Frequent itemsets of size 2 at support threshold 0.01 = 11
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 10
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 7
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 8
# Frequent itemsets of size 2 at support threshold 0.01 = 9
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 7
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 3
# Frequent itemsets of size 1 at support threshold 0.01 = 6
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 17
# Frequent itemsets of size 2 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 10
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 9
# Frequent itemsets of size 2 at support threshold 0.01 = 2
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 23
# Frequent itemsets of size 2 at support threshold 0.01 = 45
# Frequent itemsets of size 3 at support threshold 0.01 = 51
# Frequent itemsets of size 1 at support threshold 0.01 = 13
# Frequent itemsets of size 2 at support threshold 0.01 = 12
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 16
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 9
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 8
# Frequent itemsets of size 2 at support threshold 0.01 = 1
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 18
# Frequent itemsets of size 2 at support threshold 0.01 = 19
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 23
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 12
# Frequent itemsets of size 2 at support threshold 0.01 = 8
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 26
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 5
# Frequent itemsets of size 1 at support threshold 0.01 = 17
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 17
# Frequent itemsets of size 2 at support threshold 0.01 = 11
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 25
# Frequent itemsets of size 2 at support threshold 0.01 = 9
# Frequent itemsets of size 3 at support threshold 0.01 = 6
# Frequent itemsets of size 1 at support threshold 0.01 = 27
# Frequent itemsets of size 2 at support threshold 0.01 = 10
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 18
# Frequent itemsets of size 2 at support threshold 0.01 = 1
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 12
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 17
# Frequent itemsets of size 2 at support threshold 0.01 = 7
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 22
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 25
# Frequent itemsets of size 2 at support threshold 0.01 = 7
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 14
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 7
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 16
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 13
# Frequent itemsets of size 2 at support threshold 0.01 = 18
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 25
# Frequent itemsets of size 2 at support threshold 0.01 = 8
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 12
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 13
# Frequent itemsets of size 2 at support threshold 0.01 = 9
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 17
# Frequent itemsets of size 2 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 11
# Frequent itemsets of size 2 at support threshold 0.01 = 3
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 9
# Frequent itemsets of size 2 at support threshold 0.01 = 13
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 9
# Frequent itemsets of size 2 at support threshold 0.01 = 12
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 27
# Frequent itemsets of size 2 at support threshold 0.01 = 8
# Frequent itemsets of size 3 at support threshold 0.01 = 12
# Frequent itemsets of size 1 at support threshold 0.01 = 20
# Frequent itemsets of size 2 at support threshold 0.01 = 1
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 19
# Frequent itemsets of size 2 at support threshold 0.01 = 11
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 13
# Frequent itemsets of size 2 at support threshold 0.01 = 7
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 18
# Frequent itemsets of size 2 at support threshold 0.01 = 1
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 10
# Frequent itemsets of size 2 at support threshold 0.01 = 7
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 12
# Frequent itemsets of size 2 at support threshold 0.01 = 7
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 15
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 12
# Frequent itemsets of size 2 at support threshold 0.01 = 17
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 24
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 26
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 26
# Frequent itemsets of size 2 at support threshold 0.01 = 9
# Frequent itemsets of size 3 at support threshold 0.01 = 4
# Frequent itemsets of size 1 at support threshold 0.01 = 17
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 14
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 22
# Frequent itemsets of size 2 at support threshold 0.01 = 1
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 23
# Frequent itemsets of size 2 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 18
# Frequent itemsets of size 2 at support threshold 0.01 = 7
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 14
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 17
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 19
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 16
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 9
# Frequent itemsets of size 2 at support threshold 0.01 = 8
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 22
# Frequent itemsets of size 2 at support threshold 0.01 = 1
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 8
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 17
# Frequent itemsets of size 2 at support threshold 0.01 = 8
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 11
# Frequent itemsets of size 2 at support threshold 0.01 = 9
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 20
# Frequent itemsets of size 2 at support threshold 0.01 = 7
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 12
# Frequent itemsets of size 2 at support threshold 0.01 = 8
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 11
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 6
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 16
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 15
# Frequent itemsets of size 2 at support threshold 0.01 = 13
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 10
# Frequent itemsets of size 2 at support threshold 0.01 = 8
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 12
# Frequent itemsets of size 2 at support threshold 0.01 = 7
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 25
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 24
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 17
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 9
# Frequent itemsets of size 2 at support threshold 0.01 = 16
# Frequent itemsets of size 3 at support threshold 0.01 = 10
# Frequent itemsets of size 1 at support threshold 0.01 = 19
# Frequent itemsets of size 2 at support threshold 0.01 = 24
# Frequent itemsets of size 3 at support threshold 0.01 = 26
# Frequent itemsets of size 1 at support threshold 0.01 = 11
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 9
# Frequent itemsets of size 2 at support threshold 0.01 = 8
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 19
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 15
# Frequent itemsets of size 2 at support threshold 0.01 = 1
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 10
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 18
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 3
# Frequent itemsets of size 1 at support threshold 0.01 = 20
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 8
# Frequent itemsets of size 2 at support threshold 0.01 = 2
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 16
# Frequent itemsets of size 2 at support threshold 0.01 = 2
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 34
# Frequent itemsets of size 2 at support threshold 0.01 = 354
# Frequent itemsets of size 3 at support threshold 0.01 = 2019
# Frequent itemsets of size 1 at support threshold 0.01 = 24
# Frequent itemsets of size 2 at support threshold 0.01 = 1
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 22
# Frequent itemsets of size 2 at support threshold 0.01 = 3
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 16
# Frequent itemsets of size 2 at support threshold 0.01 = 2
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 18
# Frequent itemsets of size 2 at support threshold 0.01 = 8
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 17
# Frequent itemsets of size 2 at support threshold 0.01 = 16
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 13
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 9
# Frequent itemsets of size 2 at support threshold 0.01 = 2
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 12
# Frequent itemsets of size 2 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 14
# Frequent itemsets of size 2 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 7
# Frequent itemsets of size 2 at support threshold 0.01 = 1
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 10
# Frequent itemsets of size 2 at support threshold 0.01 = 10
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 8
# Frequent itemsets of size 2 at support threshold 0.01 = 2
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 14
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 7
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 4
# Frequent itemsets of size 2 at support threshold 0.01 = 7
# Frequent itemsets of size 3 at support threshold 0.01 = 3
# Frequent itemsets of size 1 at support threshold 0.01 = 8
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 8
# Frequent itemsets of size 2 at support threshold 0.01 = 1
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 19
# Frequent itemsets of size 2 at support threshold 0.01 = 18
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 8
# Frequent itemsets of size 2 at support threshold 0.01 = 9
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 10
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 25
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 13
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 10
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# ...
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 27
# Frequent itemsets of size 2 at support threshold 0.01 = 13
# Frequent itemsets of size 3 at support threshold 0.01 = 4
# Frequent itemsets of size 1 at support threshold 0.01 = 44
# Frequent itemsets of size 2 at support threshold 0.01 = 20
# Frequent itemsets of size 3 at support threshold 0.01 = 18
# Frequent itemsets of size 1 at support threshold 0.01 = 14
# Frequent itemsets of size 2 at support threshold 0.01 = 11
# Frequent itemsets of size 3 at support threshold 0.01 = 10
# Frequent itemsets of size 1 at support threshold 0.01 = 9
# Frequent itemsets of size 2 at support threshold 0.01 = 2
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 40
# Frequent itemsets of size 2 at support threshold 0.01 = 1
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 31
# Frequent itemsets of size 2 at support threshold 0.01 = 68
# Frequent itemsets of size 3 at support threshold 0.01 = 403
# Frequent itemsets of size 1 at support threshold 0.01 = 33
# Frequent itemsets of size 2 at support threshold 0.01 = 26
# Frequent itemsets of size 3 at support threshold 0.01 = 20
# Frequent itemsets of size 1 at support threshold 0.01 = 32
# Frequent itemsets of size 2 at support threshold 0.01 = 12
# Frequent itemsets of size 3 at support threshold 0.01 = 10
# Frequent itemsets of size 1 at support threshold 0.01 = 43
# Frequent itemsets of size 2 at support threshold 0.01 = 72
# Frequent itemsets of size 3 at support threshold 0.01 = 134
# Frequent itemsets of size 1 at support threshold 0.01 = 13
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 26
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 2
# Frequent itemsets of size 2 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 28
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 29
# Frequent itemsets of size 2 at support threshold 0.01 = 1
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 28
# Frequent itemsets of size 2 at support threshold 0.01 = 7
# Frequent itemsets of size 3 at support threshold 0.01 = 6
# Frequent itemsets of size 1 at support threshold 0.01 = 29
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 16
# Frequent itemsets of size 2 at support threshold 0.01 = 8
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 13
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 34
# Frequent itemsets of size 2 at support threshold 0.01 = 72
# Frequent itemsets of size 3 at support threshold 0.01 = 464
# Frequent itemsets of size 1 at support threshold 0.01 = 7
# Frequent itemsets of size 2 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 27
# Frequent itemsets of size 2 at support threshold 0.01 = 2
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 23
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 18
# Frequent itemsets of size 2 at support threshold 0.01 = 2
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 31
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 24
# Frequent itemsets of size 2 at support threshold 0.01 = 10
# Frequent itemsets of size 3 at support threshold 0.01 = 5
# Frequent itemsets of size 1 at support threshold 0.01 = 18
# Frequent itemsets of size 2 at support threshold 0.01 = 7
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 36
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 4
# Frequent itemsets of size 1 at support threshold 0.01 = 3
# Frequent itemsets of size 2 at support threshold 0.01 = 1
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 23
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 31
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 4
# Frequent itemsets of size 1 at support threshold 0.01 = 21
# Frequent itemsets of size 2 at support threshold 0.01 = 2
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 8
# Frequent itemsets of size 2 at support threshold 0.01 = 3
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 27
# Frequent itemsets of size 2 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 34
# Frequent itemsets of size 2 at support threshold 0.01 = 60
# Frequent itemsets of size 3 at support threshold 0.01 = 115
# Frequent itemsets of size 1 at support threshold 0.01 = 24
# Frequent itemsets of size 2 at support threshold 0.01 = 26
# Frequent itemsets of size 3 at support threshold 0.01 = 21
# Frequent itemsets of size 1 at support threshold 0.01 = 19
# Frequent itemsets of size 2 at support threshold 0.01 = 12
# Frequent itemsets of size 3 at support threshold 0.01 = 8
# Frequent itemsets of size 1 at support threshold 0.01 = 31
# Frequent itemsets of size 2 at support threshold 0.01 = 11
# Frequent itemsets of size 3 at support threshold 0.01 = 9
# Frequent itemsets of size 1 at support threshold 0.01 = 19
# Frequent itemsets of size 2 at support threshold 0.01 = 8
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 17
# Frequent itemsets of size 2 at support threshold 0.01 = 7
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 17
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 20
# Frequent itemsets of size 2 at support threshold 0.01 = 2
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 34
# Frequent itemsets of size 2 at support threshold 0.01 = 66
# Frequent itemsets of size 3 at support threshold 0.01 = 413
# Frequent itemsets of size 1 at support threshold 0.01 = 4
# Frequent itemsets of size 2 at support threshold 0.01 = 2
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 33
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 7
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 16
# Frequent itemsets of size 2 at support threshold 0.01 = 9
# Frequent itemsets of size 3 at support threshold 0.01 = 4
# Frequent itemsets of size 1 at support threshold 0.01 = 31
# Frequent itemsets of size 2 at support threshold 0.01 = 9
# Frequent itemsets of size 3 at support threshold 0.01 = 3
# Frequent itemsets of size 1 at support threshold 0.01 = 33
# Frequent itemsets of size 2 at support threshold 0.01 = 8
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 20
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 33
# Frequent itemsets of size 2 at support threshold 0.01 = 472
# Frequent itemsets of size 3 at support threshold 0.01 = 4584
# Frequent itemsets of size 1 at support threshold 0.01 = 21
# Frequent itemsets of size 2 at support threshold 0.01 = 3
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 18
# Frequent itemsets of size 2 at support threshold 0.01 = 3
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 12
# Frequent itemsets of size 2 at support threshold 0.01 = 8
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 24
# Frequent itemsets of size 2 at support threshold 0.01 = 54
# Frequent itemsets of size 3 at support threshold 0.01 = 74
# Frequent itemsets of size 1 at support threshold 0.01 = 27
# Frequent itemsets of size 2 at support threshold 0.01 = 8
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 7
# Frequent itemsets of size 2 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 17
# Frequent itemsets of size 2 at support threshold 0.01 = 7
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 18
# Frequent itemsets of size 2 at support threshold 0.01 = 3
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 3
# Frequent itemsets of size 2 at support threshold 0.01 = 1
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 8
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 40
# Frequent itemsets of size 2 at support threshold 0.01 = 85
# Frequent itemsets of size 3 at support threshold 0.01 = 569
# Frequent itemsets of size 1 at support threshold 0.01 = 6
# Frequent itemsets of size 2 at support threshold 0.01 = 2
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 32
# Frequent itemsets of size 2 at support threshold 0.01 = 28
# Frequent itemsets of size 3 at support threshold 0.01 = 15
# Frequent itemsets of size 1 at support threshold 0.01 = 12
# Frequent itemsets of size 2 at support threshold 0.01 = 2
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 18
# Frequent itemsets of size 2 at support threshold 0.01 = 16
# Frequent itemsets of size 3 at support threshold 0.01 = 8
# Frequent itemsets of size 1 at support threshold 0.01 = 31
# Frequent itemsets of size 2 at support threshold 0.01 = 16
# Frequent itemsets of size 3 at support threshold 0.01 = 5
# Frequent itemsets of size 1 at support threshold 0.01 = 26
# Frequent itemsets of size 2 at support threshold 0.01 = 11
# Frequent itemsets of size 3 at support threshold 0.01 = 5
# Frequent itemsets of size 1 at support threshold 0.01 = 7
# Frequent itemsets of size 2 at support threshold 0.01 = 1
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 3
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 15
# Frequent itemsets of size 2 at support threshold 0.01 = 14
# Frequent itemsets of size 3 at support threshold 0.01 = 6
# Frequent itemsets of size 1 at support threshold 0.01 = 12
# Frequent itemsets of size 2 at support threshold 0.01 = 6
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 9
# Frequent itemsets of size 2 at support threshold 0.01 = 22
# Frequent itemsets of size 3 at support threshold 0.01 = 35
# Frequent itemsets of size 1 at support threshold 0.01 = 15
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 13
# Frequent itemsets of size 2 at support threshold 0.01 = 2
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 8
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 17
# Frequent itemsets of size 2 at support threshold 0.01 = 47
# Frequent itemsets of size 3 at support threshold 0.01 = 129
# Frequent itemsets of size 1 at support threshold 0.01 = 14
# Frequent itemsets of size 2 at support threshold 0.01 = 5
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 29
# Frequent itemsets of size 2 at support threshold 0.01 = 74
# Frequent itemsets of size 3 at support threshold 0.01 = 224
# Frequent itemsets of size 1 at support threshold 0.01 = 20
# Frequent itemsets of size 2 at support threshold 0.01 = 4
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 12
# Frequent itemsets of size 2 at support threshold 0.01 = 9
# Frequent itemsets of size 3 at support threshold 0.01 = 2
# Frequent itemsets of size 1 at support threshold 0.01 = 8
# Frequent itemsets of size 2 at support threshold 0.01 = 2
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 4
# Frequent itemsets of size 2 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 12
# Frequent itemsets of size 2 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 3
# Frequent itemsets of size 2 at support threshold 0.01 = 1
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 4
# Frequent itemsets of size 2 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 10
# Frequent itemsets of size 2 at support threshold 0.01 = 1
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 3
# Frequent itemsets of size 2 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 5
# Frequent itemsets of size 2 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 5
# Frequent itemsets of size 2 at support threshold 0.01 = 7
# Frequent itemsets of size 3 at support threshold 0.01 = 7
# Frequent itemsets of size 1 at support threshold 0.01 = 3
# Frequent itemsets of size 2 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 7
# Frequent itemsets of size 2 at support threshold 0.01 = 1
# Frequent itemsets of size 3 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 1
# Frequent itemsets of size 2 at support threshold 0.01 = 0
# Frequent itemsets of size 1 at support threshold 0.01 = 3
# Frequent itemsets of size 2 at support threshold 0.01 = 2
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 3
# Frequent itemsets of size 2 at support threshold 0.01 = 2
# Frequent itemsets of size 3 at support threshold 0.01 = 1
# Frequent itemsets of size 1 at support threshold 0.01 = 0

# %% [markdown]
# ### Association rules shows 'fried onions' imply 'Tony's [cheese]steaks'

# %%
## TODO
def getRules(freqItemSets, confidence=0.8):
    """Return all association rules with minimum confidence
    
    Return value is a list of pairs, with the first component 
    being a list-valued frequent itemset of the form I-{j} and 
    the second a singleton frequent item j
    
    freqItemSets: dictionary returned by A-Priori algorithm
    confidence: minimum confidence
    """
    n = max(freqItemSets.keys())-1  # last pass of apriori 
    rules = []
    for itemset in freqItemSets[n]:
        if len(itemset) > 1:
            # itemset has n items
            for i in range(1,n): # number of items on RHS of a possible rule
                for rhs in combinations(itemset, i):
                    lhs = itemset - set(rhs)
                    c = freqItemSets[n][itemset]/freqItemSets[len(lhs)][lhs]
                    if c >= confidence:
                        #print(c)
                        rules.append((list(lhs), list(rhs)))
    return rules

# %%
## DO NOT MODIFY
for lhs, rhs in getRules(freqsets, confidence=0.5):
    print("{0} -> {1}".format(lhs, rhs))
# Out:
# ['TONY L STEAK'] -> ['FRIED ONIONS']
# ['FRIED ONIONS'] -> ['TONY L STEAK']

# %% [markdown]
# Report on your findings from the datasets using an appropriate visualization or descriptive listing, e.g. of the top ten association rules in decreasing order of confidence, or the top ten rules that have high **interest**, where *interest* of a rule $I \implies j$ is defined as the difference between the confidence of the rule and the support of $j$.

# %%
## TODO 
interest = dict()
conf = dict()
for lhs, rhs in getRules(freqsets, confidence=0.5):
    n = len(lhs+rhs)
    itemset = frozenset(lhs+rhs)
    conf[(tuple(lhs), tuple(rhs))] = freqsets[n][itemset]
    interest[(tuple(lhs), tuple(rhs))] = freqsets[n][itemset] - freqsets[len(rhs)][frozenset(rhs)]
sort_conf = sorted([(conf[k], k) for k in conf], reverse=True)
sort_interest = sorted([(interest[k], k) for k in interest], reverse=True)

# %%
for p, (lhs, rhs) in sort_conf:
    print("{0} -> {1} with confidence {2}".format(lhs, rhs, p))
# Out:
# ('TONY L STEAK',) -> ('FRIED ONIONS',) with confidence 0.010463603417165342
# ('FRIED ONIONS',) -> ('TONY L STEAK',) with confidence 0.010463603417165342

# %%
for p, (lhs, rhs) in sort_interest:
    print("{0} -> {1} with interest {2}".format(lhs, rhs, p))
# Out:
# ('TONY L STEAK',) -> ('FRIED ONIONS',) with interest -0.00033386684065121915
# ('FRIED ONIONS',) -> ('TONY L STEAK',) with interest -0.006901932349912838

# %% [markdown]
# ### Grab a random location and see if it has frequent itemsets for a specified itemset size. If so, make a bar plot.

# %%
def randVendorFreqs(locFreqDict, groupSize=1):
    vendor = np.random.choice( list( locFreqDict.keys() ) )
    
    highFreqs = [('frequency', sorted(list(locFreqDict[vendor][groupSize].values()))[:4]),
                    ('itemGroup', sorted(list(locFreqDict[vendor][groupSize].keys()))[:4])]
    freqTable = pd.DataFrame.from_items(highFreqs)
    if len(locFreqDict[vendor][groupSize]) > 0:
        freqTable = freqTable.sort_values('frequency', ascending=False).reset_index()
        print(freqTable)
        try:
            freqTable.frequency.plot.bar()
        except AttributeError as err:
            pass
        plt.xticks(np.arange(len(freqTable)), freqTable.itemGroup, rotation = 'vertical')
        plt.ylim((0, (freqTable.frequency.iloc[-1] )*1.2))
        plt.title(vendor)
        plt.show()
    else: return 1
        #print("Vendor \'{0}\' does not have any frequent groups of size {1}" \
        #        " that meet the support threshold.".format(vendor, groupSize))
    return 0

# %%
while(randVendorFreqs(locFreqDict, 2) == 1): pass
# Out:
#    index  frequency                            itemGroup
# 0      0   0.037037   (CAN16 BUD LT LM, CAN16 BUD LIGHT)
# 1      1   0.037037   (CAN25 BUD LIGHT, CAN16 BUDWEISER)
# 2      2   0.037037  (CAN25 BUD LIGHT, CAN25 BUD LT LIM)
# 3      3   0.037037  (CAN25 BUD LT LIM, CAN16 BUDWEISER)

# %% [markdown]
# ### Dislike random selection? Choose one yourself. ('102 BREWERYTOWN') perhaps.

# %%
def getVendorFreqs(vendor, locFreqDict, groupSize=1):
    if vendor in locFreqDict:
        highFreqs = [('frequency', sorted(list(locFreqDict[vendor][groupSize].values()))[:4]),
                        ('itemGroup', sorted(list(locFreqDict[vendor][groupSize].keys()))[:4])]
        freqTable = pd.DataFrame.from_items(highFreqs)
        if len(locFreqDict[vendor][groupSize]) > 0:
            freqTable = freqTable.sort_values('frequency', ascending=False).reset_index()
            print(freqTable)
            try:
                freqTable.plot.bar()
            except AttributeError as err:
                pass
            plt.xticks(np.arange(len(freqTable)), freqTable.itemGroup, rotation = 'vertical')
            #plt.ylim(0, 100)
            plt.title(vendor)
            plt.show()
        else: print("Vendor \'{0}\' does not have any frequent groups of size {1}" \
                    " that meet the support threshold.".format(vendor, groupSize))

# %%
getVendorFreqs('102 BREWERYTOWN', locFreqDict, 1)
# Out:
#    index  frequency          itemGroup
# 0      0   0.015267  (DOGFISH IPA LPD)
# 1      1   0.015267      (MARG FRZN 1)
# 2      2   0.015267  (CAN24 MILLER LT)
# 3      3   0.015267  (CAN24 DOS EQUIS)

# %%
locFreqDict['620 BREWTOWN']
# Out:
# defaultdict(dict,
#             {0: {},
#              1: {frozenset({'CAN25 BUD LT LIM'}): 0.06666666666666667,
#               frozenset({'CAN16 BUD LT LM'}): 0.13333333333333333,
#               frozenset({'CAN24 NB DAYBLAZ'}): 0.13333333333333333,
#               frozenset({'CAN16 ANGRY ORCH'}): 0.13333333333333333,
#               frozenset({'CAN16 STLLA CIDR'}): 0.06666666666666667,
#               frozenset({'KOOZIE'}): 0.06666666666666667,
#               frozenset({'CAN24 YUENG LITE'}): 0.06666666666666667,
#               frozenset({'BTL COKE'}): 0.06666666666666667,
#               frozenset({'CAN16 FAT TIRE'}): 0.06666666666666667,
#               frozenset({'CAN16 GOOSE IPA'}): 0.06666666666666667,
#               frozenset({'CAN25 BUD LIGHT'}): 0.06666666666666667,
#               frozenset({'CAN24 MILLER LT'}): 0.06666666666666667},
#              2: {}})
